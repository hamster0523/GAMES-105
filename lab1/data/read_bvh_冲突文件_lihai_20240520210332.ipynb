# %%
from dataclasses import dataclass
from collections import deque

@dataclass
class Node:
    name : str
    offset : list
    channels : dict
    child : list
    parent : str
    first_in : bool
    
file_path = "walk60.bvh"
bvh_data = []
with open(file_path, 'r') as f:
    for line in f:
        bvh_data.append(line.split())

num_frames = 0
frame_time = 0
frames = []
joint_List = []
info_List = []
for line in bvh_data:
    this_line = line
    if(this_line[0] == "Hierarchy"): continue
    if(this_line[0] == "MOTION"): continue
    if(this_line[0] == "Frames:"):
        num_frames = int(this_line[1])
        continue
    if(this_line[0] == "Frame"):
        frame_time = float(this_line[2])
        continue
    if(this_line[0] == "{" or
       this_line[0] == "ROOT" or
       this_line[0] == "}" or
       this_line[0] == "End" or
       this_line[0] == "JOINT" or
       this_line[0] == "OFFSET" or
       this_line[0] == "CHANNELS"):
        info_List.append(this_line)
        continue
    frames.append(this_line)
    
# # 处理栈中数据
# def Process_data(stack):
#     some_data = []
#     while(stack):
#         info_pop = stack.pop()
#         if(type(info_pop) != Node and info_pop[0] == "{"):
#             break
#         elif(type(info_pop) != Node and info_pop[0] == "}"):
#             continue
#         else:
#             some_data.append(info_pop)
#     print(some_data)
#     now_node = Node(
#         name = None,
#         offset = [],
#         channels = {},
#         child = [],
#         parent = None,
#         first_in = True
#     )
#     last_node = None
#     for i in some_data:
#         # if(type(i) != Node and i[0] == "OFFSET"):
#         #     now_node.offset = [float(i[1]), float(i[2]), float(i[3])]
#         # elif(type(i) != Node  and i[0] == "CHANNELS"):
#         #     now_node.channels = {
#         #         "num_channels" : int(i[1]),
#         #         "channels" : [i[1:]]
#         #     }
#         # elif(type(i) != Node and i[0] == "JOINT"):
#         #     now_node.name = i[1]
#         # elif(type(i) == Node):
#         #     last_node = i
#         #     i += 1
#         if(type(i) == Node):
#             last_node = i
#             continue
#         if(type(i) != Node and i[0] == "OFFSET"):
#             now_node.offset = [float(i[1]), float(i[2]), float(i[3])]
#         elif(type(i) != Node and i[0] == "CHANNELS"):
#             now_node.channels = {
#                 "num_channels" : int(i[1]),
#                 "channels" : [i[1:]]}
#         elif(type(i) != Node and i[0] == "End" or i[0] == "Joint"):
#             if(i[0] == "End") : last_node.name = i[0] + i[1]
#             if(i[0] == "Joint") : last_node.name = i[1]
#             last_node.parent = now_node.name
#             now_node.child.append(last_node)
#             last_node.first_in = False
#             joint_List.append(last_node)
            
#         print(now_node)
#         print(last_node)
#     return now_node
        
    
            
len_info = len(info_List)
node_list = []
stack = deque()
# for i in range(len_info):
#     if(info_List[i][0] == "{"):
#         stack.append(info_List[i])
#         while(info_List[i][0] != "}"):
#             i += 1
#             stack.append(info_List[i])
#     elif(info_List[i][0] == "}"):
#         stack.pop()
#         print(stack.pop())
for i in range(len_info):
    if info_List[i][0] == "ROOT":
        root = Node(
             name = info_List[i][0] + info_List[i][1],
                offset = [],
                channels = {},
                child = [],
                parent = None,
                first_in = True)
        node_list.append(root)
        joint_List.append(root)
        continue
    if info_List[i][0] == "{" or info_List[i][0] == "OFFSET" or \
        info_List[i][0] == "CHANNELS" or info_List[i][0] == "End" or \
        info_List[i][0] == "JOINT":
            stack.append(info_List[i])
            continue
    if info_List[i][0] == "}":
        stack.append(info_List[i])

# %%
info_List

# %%
node_list

# %%
class Node:
    def __init__(self, name):
        self.name = name
        self.offset = None
        self.channels = []
        self.children = []

    def __repr__(self):
        return f"Node({self.name})"


def build_skeleton(bvh_data):
    stack = []
    root = None
    current_node = None

    for line in bvh_data:
        if line[0] == 'ROOT' or line[0] == 'JOINT':
            # 创建新节点
            node = Node(line[1])
            if current_node is not None:
                # 添加为当前节点的子节点
                current_node.children.append(node)
                stack.append(current_node)
            else:
                root = node
            current_node = node
        elif line[0] == 'OFFSET':
            # 设置偏移量
            current_node.offset = tuple(map(float, line[1:]))
        elif line[0] == 'CHANNELS':
            # 设置通道信息
            current_node.channels = line[2:]  # 跳过通道数量
        elif line[0] == '}':
            # 结束当前节点的定义，返回到父节点
            if stack:
                current_node = stack.pop()
        elif line[0] == 'End' and line[1] == 'Site':
            # 处理末端节点
            end_site_node = Node('End Site')
            current_node.children.append(end_site_node)
            stack.append(current_node)
            current_node = end_site_node

    return root

# 解析示例数据
bvh_data = [['ROOT', 'Hips'], ['{'], ['OFFSET', '0.00', '0.00', '0.00'], ['CHANNELS', '6', 'Xposition', 'Yposition', 'Zposition', 'Xrotation', 'Yrotation', 'Zrotation']]
skeleton = build_skeleton(info_List)
print(skeleton.children)

# %%
from dataclasses import dataclass
from collections import deque

@dataclass
class Node:
    name : str
    offset : list
    channels : dict
    child : list
    parent : str
    ID : int
    type : str
    
file_path = "walk60.bvh"
bvh_data = []
with open(file_path, 'r') as f:
    for line in f:
        bvh_data.append(line.split())

num_frames = 0
frame_time = 0
frames = []
joint_List = []
info_List = []
for line in bvh_data:
    this_line = line
    if(this_line[0] == "Hierarchy"): continue
    if(this_line[0] == "MOTION"): continue
    if(this_line[0] == "Frames:"):
        num_frames = int(this_line[1])
        continue
    if(this_line[0] == "Frame"):
        frame_time = float(this_line[2])
        continue
    if(this_line[0] == "{" or
       this_line[0] == "ROOT" or
       this_line[0] == "}" or
       this_line[0] == "End" or
       this_line[0] == "JOINT" or
       this_line[0] == "OFFSET" or
       this_line[0] == "CHANNELS"):
        info_List.append(this_line)
        continue
    frames.append(this_line)
    
offset_stack = deque()
channel_stack = deque()
node_stack = deque()
joint_List = []
node_id = 0

for info in info_List:
    if(info[0] == "ROOT"):
        node_stack.append(Node(
            name = "RootJoint",
            offset = None,
            channels = None,
            child = [],
            parent = None,
            ID = node_id,
            type = "root"
        ))
        node_id += 1
        continue
    elif info[0] == "{": continue
    elif info[0] == "OFFSET":
        offset_stack.append(list(map(float, info[1:])))
        continue
    elif info[0] == "CHANNELS":
        channel_stack.append({
            "channel_num" : int(info[1]),
            "channels" : info[2:]
        })
    elif info[0] == "JOINT":
        node_stack.append(Node(
            name = info[1],
            offset = None,
            channels = None,
            child = [],
            parent = None,
            ID = node_id,
            type = "joint"
        ))
        node_id += 1
        continue
    elif info[0] == "End":
        node_stack.append(Node(
            name = info[0] + info[1],
            offset = None,
            channels = None,
            parent = None,
            child = None,
            type = "End",
            ID = node_id
        ))
        node_id += 1
        continue
    elif info[0] == "}":
        pop_node = node_stack.pop()
        if pop_node.type == "End":
            top_node = node_stack[-1]
            pop_node.name = top_node.name + "_end"
            pop_node.parent = top_node.name
            pop_node.child = None
            offset_top = offset_stack.pop()
            pop_node.offset = offset_top
            pop_node.channels = None
            top_node.child.append(pop_node)
            joint_List.append(pop_node)
        elif pop_node.type == "joint":
            top_node = node_stack[-1]
            pop_offset = offset_stack.pop()
            pop_channels = channel_stack.pop()
            # print(pop_channels)
            pop_node.offset = pop_offset
            pop_node.channels = pop_channels
            pop_node.parent = top_node.name
            top_node.child.append(pop_node)
            joint_List.append(pop_node)
        elif pop_node.type == "root":
            pop_offset = offset_stack.pop()
            pop_channels = channel_stack.pop()
            # print(pop_channels)
            pop_node.offset = pop_offset
            pop_node.channels = pop_channels
            pop_node.parent = None
            joint_List.append(pop_node)
        continue

# %%
for node in joint_List:
    if(node.name == "RootJoint"):
        print(len(node.child))

# %%
from read_bvh import Bone_Tree

bone_tree = Bone_Tree('walk60.bvh')

# %%
bone_tree.all_channels

# %%
bone_tree.channels

# %%
bone_tree.frames[0]

# %%
from read_bvh import Bone_Tree

# %%
import numpy as np
from scipy.spatial.transform import Rotation as R
def load_motion_data(bvh_file_path):
    """part2 辅助函数，读取bvh文件"""
    with open(bvh_file_path, 'r') as f:
        lines = f.readlines()
        for i in range(len(lines)):
            if lines[i].startswith('Frame Time'):
                break
        motion_data = []
        for line in lines[i+1:]:
            data = [float(x) for x in line.split()]
            if len(data) == 0:
                break
            motion_data.append(np.array(data).reshape(1,-1))
        motion_data = np.concatenate(motion_data, axis=0)
    return motion_data

# %%
motion_data = load_motion_data(bvh_file_path= 'walk60.bvh')

# %%
motion_data

# %%
print(motion_data.shape)

# %%
motion_data_my = Bone_Tree('walk60.bvh').frames

# %%
motion_data_my

# %%
from read_bvh import Bone_Tree
tree = Bone_Tree(bvh_file_path= 'walk60.bvh')

# %%
tree.sorted_joint_list

# %%
name_list = []
id_list = []
parent_list = []
offset_list = []
for joint in tree.sorted_joint_list:
    name_list.append(joint.name)
    id_list.append(joint.ID)
    parent_list.append(joint.parent["parent_id"])
    offset_list.append(joint.offset)
print(name_list)
print(id_list)
print(parent_list)
print(len(offset_list))
print(tree.node_count)

# %%
tree.joint_List

# %%
from read_bvh import Bone_Tree
tree = Bone_Tree(bvh_file_path= 'walk60.bvh')

# %%
print(tree.joint_name)
print(tree.)
print(tree.joint_parent)

# %%
from read_bvh import Bone_Tree
from dataclasses import dataclass
from collections import deque
import numpy as np
from scipy.spatial.transform import Rotation as R

bone_tree = Bone_Tree("walk60.bvh")

# %%
joint_List = bone_tree.sorted_joint_list
joint_name = bone_tree.joint_name
joint_parent = bone_tree.joint_parent
joint_offset = bone_tree.joint_offset
motion_data = bone_tree.frames


joint_List

# %%
def find_parent_rotation(Q, parent_index):
    for joint in Q:
        if joint['id'] == parent_index:
            return joint['rotation']
        
def find_parent_location(Q, parent_index):
    for joint in Q:
        if joint['id'] == parent_index:
            return joint['location']

def forward_kinematics(
        joint_list: list,
        motion_data: list,
    ) -> np.array:
        # Q4 = Q3R4 = Q2R3R4 = Q1R2R3R4 = Q0R1R2R3R4 = R0R1R2R3R4
        # DP 累推
        # return : joint_position : shape -> num_frames * num_joint * 3
        # return : joint_rotation : shape -> num_frames * num_joint * 4 (quaternion)
        joint_all_frames_info_rotation_local = []
        for frame in motion_data:
            # Q : this_frame joint_rotation -> shape : num_joint * 4
            Q = []
            # Only root joint has translation
            T0 = None
            # joint_list is sorted by ID : the sequence follow the bvh hierarchy
            for joint in joint_list:
                if joint.type == "root":
                    # root channels is 6 : first 3 is translate , second 3 is rotation
                    translate = frame[:3]
                    rotation = frame[3:6]
                    # translate_euler = R.from_euler('XYZ', translate, degrees=True)
                    T0 = np.array(translate)
                    rotation_euler = R.from_euler("XYZ", rotation, degrees=True)
                    rotation_quaternion = rotation_euler.as_quat()
                    # root's location is (0,0,0)
                    Q.append(
                        {
                            "id": 0,
                            "rotation" : rotation_quaternion,
                            "location" : np.array([0, 0, 0]),
                        }
                    )
                elif joint.type == "joint":
                    joint_index = joint.ID - 1
                    parent_index = joint.parent["parent_id"]
                    joint_rotation = frame[
                       joint.channel_index : joint.channel_index + 3
                    ]
                    #print(joint.ID)
                    #print(joint_index)
                    joint_rotation = np.array(list(map(float, joint_rotation)))
                    # parent_roation is quaternion
                    parent_rotation = find_parent_rotation(Q, parent_index)
                    #print(joint_rotation)
                    #print(type(joint_rotation))
                    #print(R.from_euler("xyz", joint_rotation, degrees=True))
                    #print(R.from_euler("xyz", joint_rotation, degrees=True).as_matrix())
                    this_joint_rotation = R.from_matrix(
                        R.from_quat(parent_rotation).as_matrix()
                        @ R.from_euler("xyz", joint_rotation, degrees=True).as_matrix()
                    ).as_quat()
                    # print(this_joint_rotation)
                    # print("--------------")
                    # parent_location is np.array -> 3 dim vec
                    parent_location = find_parent_location(Q, parent_index)
                    # joint_offset is np.array -> 3 dim vec
                    joint_offset = joint.offset
                    # ID == 1 -> need translate
                    if joint.ID == 1:
                        T0 = list(map(float, T0))
                        this_joint_location = (
                            parent_location
                            + R.from_quat(parent_rotation).apply(np.array(joint_offset))
                            + T0
                        )
                    else:
                        this_joint_location = (
                            parent_location + R.from_quat(parent_rotation).apply(np.array(joint_offset))
                        )
                    Q.append(
                        {
                            'id' : joint.ID,
                            "rotation" : this_joint_rotation,
                            "location" : this_joint_location,
                        }
                    )
                elif joint.type == "End":
                    parent_index = joint.parent["parent_id"]
                    parent_rotation = find_parent_rotation(Q, parent_index)
                    parent_location = find_parent_location(Q, parent_index)
                    this_offset = joint.offset
                    this_joint_location = parent_location + R.from_quat(parent_rotation).apply(np.array(this_offset))
                    Q.append(
                        {
                            "id" : joint.ID,
                            "rotation" : None,
                            "location" : this_joint_location
                        }
                    )
            joint_all_frames_info_rotation_local.append(Q)
        return joint_all_frames_info_rotation_local

# %%
joint_all_position = forward_kinematics(
    joint_List,
    motion_data = motion_data)
print(np.array(joint_all_position).shape)

# %%
print(joint_all_position[0])

# %%
from read_bvh import Bone_Tree
from dataclasses import dataclass
from collections import deque
import numpy as np
from scipy.spatial.transform import Rotation as R

bone_tree = Bone_Tree("walk60.bvh")

# %%
bone_tree.all_frame_location

# %%
bone_tree.all_frame_rotation

# %%
from read_bvh import Bone_Tree
from scipy.spatial.transform import Rotation as R
import numpy as np

# %%
bone_tree_A_pos = Bone_Tree("A_pose_run.bvh")
bone_tree_T_pos = Bone_Tree("walk60.bvh")

# %%
bone_tree_A_pos.joint_name_without_end

# %%
bone_tree_A_pos.joint_parent

# %%
bone_tree_T_pos.joint_parent

# %%
bone_tree_A_pos_joint_name_without_end = bone_tree_A_pos.joint_name_without_end
bone_tree_T_pos_joint_name_without_end = bone_tree_T_pos.joint_name_without_end
A_pos_frame = bone_tree_A_pos.frames
A_pos_processed_frame = bone_tree_A_pos.process_A_pos_frame(A_pos_frame = A_pos_frame,
                                                            T_pos_joint_name_without_end = bone_tree_T_pos_joint_name_without_end,
                                                            A_pos_joint_name_without_end = bone_tree_A_pos_joint_name_without_end)

# %%
from scipy.spatial.transform import Rotation as R
# first step -> calculate all Q-matrices
# Q-matrix is transfrom T-pos to A-pos
def calculate_Q_matrix(A_pos_frame : list, T_pos_frame : list, joint_name : list) -> list:
    Q_matrix_all_frame = [] # -> dict : {joint_name : Q_matrix} -> shape:(num_frames, num_joints)
    for A_pos_frame_this, T_pos_frame_this in zip(A_pos_frame, T_pos_frame):
        Q_matrix_this_frame = []
        print(joint_name)
        for idx, joint in enumerate(joint_name):
            A_pos_rotation = A_pos_frame_this[3 + idx * 3 : 6 + idx * 3]
            # print("A_pos_rotation : ", A_pos_rotation)
            T_pos_rotation = T_pos_frame_this[3 + idx * 3 : 6 + idx * 3]
            # print("T_pos_rotation : ", T_pos_rotation)
            A_rotation_matrix = R.from_euler("XYZ", A_pos_rotation, degrees = True)
            print("A_rotation_matrix : ", A_rotation_matrix.as_matrix())
            T_rotation_matrix = R.from_euler("XYZ", T_pos_rotation, degrees = True)
            print("T_rotation_matrix : ", T_rotation_matrix.as_matrix())
            # target_matrix * T_rotation_matrix = A_rotation_matrix
            # so -> target_matrix = A_rotation_matrix * T_rotation_matrix.inv()
            Q_this_joint = A_rotation_matrix * T_rotation_matrix.inv()
            Q_matrix_this_frame.append(
                {
                    "joint_name" : joint,
                    "Q_matrix" : Q_this_joint
                }
            )
        Q_matrix_all_frame.append(Q_matrix_this_frame)
    return Q_matrix_all_frame

# %%
Q_matrix = calculate_Q_matrix(A_pos_frame = A_pos_processed_frame, 
                              T_pos_frame = bone_tree_T_pos.frames,
                              joint_name = bone_tree_A_pos.joint_name_without_end)
print(Q_matrix)

# %%
Q_matrix

# %%
# ok -> all_Q_has_been_calculated
Q_matrix[0][0]['Q_matrix'].as_matrix() 
print((Q_matrix[0]))

# %%
bone_tree_A_pos.sorted_joint_list

# %%
Q_matrix[1]

# %%
def find_node(node_list : list, joint_name : str):
    for node in node_list:
        if(node.name == joint_name):
            return node

def find_Q(Q_matrix : list , joint_name : str):
    for Q in Q_matrix:
        if(Q['joint_name'] == joint_name):
            return Q['Q_matrix']

# for root node -> Rotation_in_A_pos = Rotation_in_T_pos * Q(from_T_pos_to_A_pos)^T
# for none root node -> Rotation_in_A_pos = Q(parent_from_T_pos_to_A_pos) * Rotation_in_T_pos * Q(this_joint_from_T_pos_to_A_pos)

def motion_retarget(Q_matrix : list, T_pos_all_frames : list, node_list_in_A_pos : list, node_list_in_T_pos : list) -> list:
    # input : rotation_in_A_pos_all_frames,
    #         tranformation_matrix_from_T_pos_to_A_pos
    #         rotation_in_T_pos_all_frames
    # output : retargeting_motion_from_A_pos_to_T_pos_all_frames
    all_frame_new_rotation_in_T_pos = []
    for idx, T_pos_frame in enumerate(T_pos_all_frames):
        this_T_pos_frame = T_pos_frame
        # print(this_T_pos_frame)
        # print(idx)
        # print(Q_matrix)
        this_frame_all_Q_matrix = Q_matrix[int(idx)]
        # print(this_frame_all_Q_matrix)
        this_frame_new_rotation_in_T_pos = []
        for idx_joint, one_Q_matrix in enumerate(this_frame_all_Q_matrix):
            joint_name = one_Q_matrix['joint_name']
            Q_matrix_this_joint = one_Q_matrix['Q_matrix']
            this_joint_rotation_in_T_pos = this_T_pos_frame[3 + 3 * idx_joint : 6 + 3 * idx_joint]
            joint_node_in_A_pos = find_node(node_list_in_A_pos, joint_name)
            joint_parent_name = joint_node_in_A_pos.parent['parent_name'] 
            parent_Q_matrix = find_Q(this_frame_all_Q_matrix, joint_parent_name)
            if(joint_node_in_A_pos.type == 'root'):
                # this is a root node
                # print("this_joint_rotation_in_T_pos: ", this_joint_rotation_in_T_pos)
                # print("Q_matrix_this_joint: ", Q_matrix_this_joint.as_matrix())
                # add T_pos translation to the new_frame_info
                this_frame_new_rotation_in_T_pos.append(this_T_pos_frame[0 : 3])
                B_rotation = R.from_euler("XYZ", this_joint_rotation_in_T_pos, degrees = True).as_matrix() * Q_matrix_this_joint.as_matrix().transpose()
                this_frame_new_rotation_in_T_pos.append(R.from_matrix(B_rotation).as_euler("XYZ", degrees = True).tolist())
                continue
            else:
                B_rotation = parent_Q_matrix.as_matrix() * R.from_euler("XYZ", this_joint_rotation_in_T_pos, degrees = True).as_matrix() * Q_matrix_this_joint.as_matrix().transpose()
                this_frame_new_rotation_in_T_pos.append(R.from_matrix(B_rotation).as_euler("XYZ", degrees = True).tolist())
        all_frame_new_rotation_in_T_pos.append(np.array(this_frame_new_rotation_in_T_pos).reshape(-1, len(this_T_pos_frame)).tolist()) 
    return np.array(all_frame_new_rotation_in_T_pos).squeeze().tolist()

# %%
new_frame = motion_retarget(
    Q_matrix,
    T_pos_all_frames = bone_tree_T_pos.frames,
    node_list_in_A_pos = bone_tree_A_pos.sorted_joint_list,
    node_list_in_T_pos = bone_tree_T_pos.sorted_joint_list
)

# %%
new_frame

# %%
from read_bvh import Bone_Tree
import numpy as np

bone_tree_T_pos = Bone_Tree("walk60.bvh")

# %%
a_path_b = bone_tree_T_pos.get_path_from_Ajoint_To_Bjoint("lToeJoint_end", "RootJoint")

# %%
joint_offsets = bone_tree_T_pos.joint_offset
# len(joint_offsets)
root_joint_name = a_path_b[1][-1]
end_joint_name = a_path_b[1][0]
# print(root_joint_name, end_joint_name)
root_joint_name_index = bone_tree_T_pos.joint_name.index(root_joint_name)
end_joint_name_index = bone_tree_T_pos.joint_name.index(end_joint_name)
print(root_joint_name_index, end_joint_name_index)
# Out:
# 0 5

# %%
root_joint_offset = joint_offsets[root_joint_name_index]
root_joint_offset
# Out:
# array([0., 0., 0.])

# %%
end_joint_offset = joint_offsets[end_joint_name_index]
end_joint_offset
# Out:
# array([0.01 , 0.002, 0.06 ])

# %%
primary_positions, primary_rotations = bone_tree_T_pos.get_bone_tree_primary_positions_rotations_from_AJoint_To_BJoint(
    path_info = a_path_b
 )

# %%
primary_positions, primary_rotations
# Out:
# ([array([ 0.02321566, -0.01050921,  0.21952044]),
#   array([ 0.01563993, -0.01153512,  0.159142  ]),
#   array([0.02119855, 0.05747961, 0.03828643]),
#   array([0.0740268 , 0.40404407, 0.20917308]),
#   array([0.09666573, 0.80309773, 0.30051669]),
#   array([0., 0., 0.])],
#  [array([ 0.00652976, -0.02040147, -0.01068351,  0.99971346]),
#   array([ 0.00652976, -0.02040147, -0.01068351,  0.99971346]),
#   array([ 0.07547421, -0.02394533,  0.00391293,  0.99685252]),
#   array([ 0.22701368,  0.02261524, -0.0644312 ,  0.9714947 ]),
#   array([ 0.1130767 ,  0.03588904, -0.02372451,  0.99265441]),
#   array([ 0.017026  ,  0.06643844, -0.00578745,  0.99762847])])

# %%
for posi in primary_positions:
    print(posi)
# Out:
# [ 0.02321566 -0.01050921  0.21952044]
# [ 0.01563993 -0.01153512  0.159142  ]
# [0.02119855 0.05747961 0.03828643]
# [0.0740268  0.40404407 0.20917308]
# [0.09666573 0.80309773 0.30051669]
# [0. 0. 0.]

# %%
primary_positions.reverse()

# %%
print(primary_positions)
# Out:
# [array([0., 0., 0.]), array([0.09666573, 0.80309773, 0.30051669]), array([0.0740268 , 0.40404407, 0.20917308]), array([0.02119855, 0.05747961, 0.03828643]), array([ 0.01563993, -0.01153512,  0.159142  ]), array([ 0.02321566, -0.01050921,  0.21952044])]

# %%
import torch as torch
import numpy as np

# %%
aa = np.array([x.tolist() for x in primary_rotations])

# %%
aa
# Out:
# array([[ 0.00652976, -0.02040147, -0.01068351,  0.99971346],
#        [ 0.00652976, -0.02040147, -0.01068351,  0.99971346],
#        [ 0.07547421, -0.02394533,  0.00391293,  0.99685252],
#        [ 0.22701368,  0.02261524, -0.0644312 ,  0.9714947 ],
#        [ 0.1130767 ,  0.03588904, -0.02372451,  0.99265441],
#        [ 0.017026  ,  0.06643844, -0.00578745,  0.99762847]])

# %%
a = torch.from_numpy(aa)

# %%
a.requires_grad_(True)
# Out:
# tensor([[ 0.0065, -0.0204, -0.0107,  0.9997],
#         [ 0.0065, -0.0204, -0.0107,  0.9997],
#         [ 0.0755, -0.0239,  0.0039,  0.9969],
#         [ 0.2270,  0.0226, -0.0644,  0.9715],
#         [ 0.1131,  0.0359, -0.0237,  0.9927],
#         [ 0.0170,  0.0664, -0.0058,  0.9976]], dtype=torch.float64,
#        requires_grad=True)

# %%
print(a.grad)
# Out:
# None

# %%
len(a)
# Out:
# 6

# %%
a[0].tolist()
# Out:
# [0.006529755862589982,
#  -0.020401466056178146,
#  -0.010683507664969403,
#  0.9997134615154015]

# %%
from scipy.spatial.transform import Rotation as R
Q = []
Q.append(R.from_euler('xyz', [0, 0, 0], degrees=True).as_matrix())
for i in range(len(aa)):
     #Q.append(R.from_euler("XYZ", degrees = True, seq = a[i].tolist()))
     # print(a[i].tolist())
     # print(R.from_quat(a[i].tolist()).as_matrix())
     # print(Q[-1])
     Q.append(
        R.from_quat(a[i].tolist()).as_matrix() @ Q[-1]
    )
Q[1:]

# %%
def forward_kinematics(root_joint_pos : list, all_joint_offset : list, rotation_param_matrix : torch.Tensor)-> list:
    # do forward kinematics from a root joint to a end joint
    # return -> end joint position 
    
    # first calculate all needed rotations
    Q = []
    Q.append(
        R.from_euler("XYZ",[0,0,0], degrees = True).as_matrix()
    )
    for i in range(len(rotation_param_matrix)):
        Q.append(
            R.from_quat(rotation_param_matrix[i].tolist()).as_matrix() @ Q[-1]
        )
    # exclude the identity matrix
    Q = Q[1:]
    
    # second calculate the end joint position
    '''
    if the joint nums is 5, the final position is calculated by :
    X = p0 + R0l0 + R0R1l1 + R0R1R2l2 + R0R1R2R3l3 + R0R1R2R3R4l4
    Here p0 is root_joint_pos
         R0 - R0R1R2R3R4 is calculated in Q
         l0 - l4 - x is all offset from root joint to end joint
    '''
    final_position = np.array(root_joint_pos)
    for i in range(len(Q)):
        final_position += np.array(
            Q[i] @ all_joint_offset[i]
        )
    return final_position.tolist()

# %%
from read_bvh import Bone_Tree
from torch import torch
import numpy as np
from scipy.spatial.transform import Rotation as R

def get_joint_offset_along_path(bone_tree : Bone_Tree, path_name : list):
    path_offset_along_path = []
    
    '''
    path_name is like : ['lToeJoint_end', 'lToeJoint', 'lAnkle', 'lKnee', 'lHip', 'RootJoint']
              is from end to root joint
    '''
    all_joint_name_index = [
        bone_tree.joint_name.index(joint_name)
        for joint_name in path_name
    ]
    
    path_offset_along_path = [
        bone_tree.joint_offset[joint_name_index]
        for joint_name_index in all_joint_name_index
    ]
    # so the offset is from end to root joint
    path_offset_along_path.reverse()
    return path_offset_along_path
    
def forward_kinematics(root_joint_pos : list, all_joint_offset : list, rotation_param_matrix : torch.Tensor)-> list:
    # do forward kinematics from a root joint to a end joint
    # return -> end joint position 
    
    # first calculate all needed rotations
    Q = []
    Q.append(
        R.from_euler("XYZ",[0,0,0], degrees = True).as_matrix()
    )
    for i in range(len(rotation_param_matrix)):
        Q.append(
            R.from_quat(rotation_param_matrix[i].tolist()).as_matrix() @ Q[-1]
        )
    # exclude the identity matrix
    Q = Q[1:]
    
    # second calculate the end joint position
    '''
    if the joint nums is 5, the final position is calculated by :
    X = p0 + R0l0 + R0R1l1 + R0R1R2l2 + R0R1R2R3l3 + R0R1R2R3R4l4
    Here p0 is root_joint_pos
         R0 - R0R1R2R3R4 is calculated in Q
         l0 - l4 - x is all offset from root joint to end joint
    '''
    final_position = np.array(root_joint_pos)
    for i in range(len(Q)):
        final_position += np.array(
            Q[i] @ all_joint_offset[i]
        )
    return torch.from_numpy(final_position)

def inverse_kinematics(
    bone_tree: Bone_Tree,
    path_info: list,
    # joint_positions: list,
    # joint_orientations: list,
    target_pos: list,
) -> list:
    """
    input : path_info : list -> from AJoint To BJoint path info
            joint_positions : list -> no IK joint positions
            joint_orientations : list -> no IK joint orientations
            target_pos : list -> target position
    output :
            joint_positions : list -> IK joint positions
            joint_orientations : list -> IK joint orientations
    """
    # in gradient descent -> update the rotate parameter of each joint
    # then calculate the new joint position
    # the primart position for root joint is all the same -> not change
    # every iterate -> do forward kinamatics to calculate the end joint position

    '''
    all needed info :
    thresold : 0.001
    learning_rate : 0.01
    '''
    thresold = 0.001
    learning_rate = 0.01
    epochs = 1000

    try:
        path_index = path_info[0]
        path_name = path_info[1]
    except:
        if len(path_index) == 2:
            raise ValueError("more path here not supported")
    # this only process one path case

    primary_positions, primary_rotations = (
        bone_tree.get_bone_tree_primary_positions_rotations_from_AJoint_To_BJoint(
            path_info = path_info
        )
    )
    
    # offset from root joint to end joint
    root_to_end_offset = get_joint_offset_along_path(bone_tree, path_name)

    # reverse -> from RootJoint to end joint
    primary_positions.reverse()
    primary_rotations.reverse()

    # type : np.ndarray
    primary_positions_root = primary_positions[0]

    # create a rotation parameter matrix
    rotation_matrix = torch.from_numpy(
        np.array([x.tolist() for x in primary_rotations])
    ).requires_grad_(True)
    """
    torch array like :
    tensor([[ 0.0065, -0.0204, -0.0107,  0.9997],
        [ 0.0065, -0.0204, -0.0107,  0.9997],
        [ 0.0755, -0.0239,  0.0039,  0.9969],
        [ 0.2270,  0.0226, -0.0644,  0.9715],
        [ 0.1131,  0.0359, -0.0237,  0.9927],
        [ 0.0170,  0.0664, -0.0058,  0.9976]], dtype=torch.float64)
    """
    final_position = forward_kinematics(
        root_joint_pos = primary_positions_root,
        all_joint_offset = root_to_end_offset,
        rotation_param_matrix = rotation_matrix
    )
    # x = torch.from_numpy(np.array(final_position) 
    #                      - np.array(target_pos)).requires_grad_(True)
    # y = 0.5 * torch.dot(x, x)
    
    optimizer = torch.optim.SGD([rotation_matrix], lr = learning_rate)
    for epoch in range(epochs):
        optimizer.zero_grad()
        final_position = forward_kinematics(
            root_joint_pos = primary_positions_root,
            all_joint_offset = root_to_end_offset,
            rotation_param_matrix = rotation_matrix
        )
        # x = torch.tensor(final_position, dtype=torch.float64) \
        #     - torch.tensor(target_pos, dtype=torch.float64)
        # y = 0.5 * torch.dot(x, x)
        final_position_tensor = torch.tensor(final_position, dtype=torch.float64, requires_grad=True)
        target_pos_tensor = torch.tensor(target_pos, dtype=torch.float64)
        x = final_position_tensor - target_pos_tensor
        y = 0.5 * torch.dot(x, x)
        y.backward()
        optimizer.step()
        if epoch % 10 == 0:
            print(f"epoch {epoch} loss {y.item()}")
        
        if y.item() < thresold:
            break
        
    final_joint_positions = forward_kinematics(
        root_joint_pos = primary_positions_root,
        all_joint_offset = root_to_end_offset,
        rotation_param_matrix = rotation_matrix
    )
    final_orientation = rotation_matrix.detach().numpy()
    
    return final_joint_positions, final_orientation

# %%
bone_tree_T_pos = Bone_Tree("walk60.bvh")
path_info = bone_tree_T_pos.get_path_from_Ajoint_To_Bjoint("lToeJoint_end", "RootJoint")
target_pos = [0.35, 0.45, 0.13]

# %%
final_joint_positions, final_orientation = inverse_kinematics(
    bone_tree = bone_tree_T_pos,
    path_info = path_info,
    target_pos = target_pos
)

# %%
from read_bvh import Bone_Tree
from torch import torch
import numpy as np
from scipy.spatial.transform import Rotation as R


def get_joint_offset_along_path(bone_tree : Bone_Tree, path_name : list):
    path_offset_along_path = []
    
    '''
    path_name is like : ['lToeJoint_end', 'lToeJoint', 'lAnkle', 'lKnee', 'lHip', 'RootJoint']
              is from end to root joint
    '''
    all_joint_name_index = [
        bone_tree.joint_name.index(joint_name)
        for joint_name in path_name
    ]
    
    path_offset_along_path = [
        bone_tree.joint_offset[joint_name_index]
        for joint_name_index in all_joint_name_index
    ]
    # so the offset is from end to root joint
    path_offset_along_path.reverse()
    return path_offset_along_path

def forward_kinematics(
    root_positions_tensor : torch.Tensor,
    root_to_end_offset_tensor : torch.Tensor,
    root_to_end_rotations_tensor : torch.Tensor
) -> torch.Tensor:

    # # calculate every joint positions
    # for i in range(len(num_joints)):
    #     current_joint_name = path_names[i]
    #     current_joint_index = path_index[i]
    #     current_joint_offset = root_to_end_offset_tensor[i]
    #     current_Node = joint_list[current_joint_index]
    #     parent_joint_index = joint_parent[current_joint_index]
    #     parent_joint_name =  joint_names[parent_joint_index]
    #     if current_Node.type == 'root':
    #       chains.append(
    #           {
    #               "name" : current_Node.name,
    #               "position" : root_positions_tensor,
    #               "orientation" : root_to_end_rotations_tensor[0]
    #           }
    #       )  
    #     elif current_Node.type == 'joint':
    #         parent_position = find_parent_positions(chains, parent_joint_name)
    
    # calculate all joint orientations
    Q = []
    Q.append(
        R.from_euler("XYZ", [0, 0, 0], degrees=True).as_matrix()
    )
    for i in range(len(root_to_end_rotations_tensor)):
        Q.append(
            R.from_quat(root_to_end_rotations_tensor[i].tolist()).as_matrix() \
                @ Q[-1]
        )
    '''
    all needed orientations are calculated , here is list
    R0 R0R1 R0R1R2 ...
    '''    
    # exclude the identity matrix
    Q = Q[1:]
    
    # calculate all joint positions
    joint_position_list = []
    joint_position_list.append(root_positions_tensor.tolist())
    for i in range(len(Q)):
        joint_position_list.append(
            Q[i] @ root_to_end_offset_tensor[i].tolist() + joint_position_list[-1]
        )
    
    # convert to tensor
    joint_position_tensor = [
        torch.tensor(data, requires_grad = True)
        for data in joint_position_list
    ]
    joint_orientation_tensor = [
        torch.tensor(data, requires_grad = True)
        for data in Q
    ]
    
    return joint_position_tensor, joint_orientation_tensor
    


def inverse_kinematics_2(
    bone_tree : Bone_Tree,
    path_info : list,
    target_pos : list
) -> list:
    threshold = 0.001
    learning_rate = 0.01
    epochs = 1000
    
    try:
        path_index = path_info[0]
        path_name  = path_info[1]
        num_joints = len(path_index)
    except:
        if(len(path_index) == 2):
            raise ValueError("two path not supported yet")
    
    # primary joint positions and  ! local ! rotations
    primary_positions, primary_rotations = bone_tree.get_bone_tree_primary_positions_rotations_from_AJoint_To_BJoint(
        path_info = path_info
    )
    #print("primary_positions : ", primary_positions)
    #print("primary_rotations : ", primary_rotations)
    # root position ->  change every iteration
    primary_positions.reverse()
    #print("root_to_end_positions : ", primary_positions)
    root_position_not_change = primary_positions[0]
    # rotations     ->  change every iteration -> calculate grad -> update
    primary_rotations.reverse()
    #print("root_to_end_rotations : ", primary_rotations)
    # offset        ->  not change every iteration
    root_to_end_offset = get_joint_offset_along_path(bone_tree = bone_tree, path_name = path_name)
    #print("root_to_end_offset : ", root_to_end_offset)
    
    
    root_to_end_positions_tensor = [
        torch.tensor(data, requires_grad = True)
        for data in primary_positions
    ]
    root_position_not_change_tensor =torch.tensor(root_position_not_change, requires_grad = True)
    root_to_end_rotations_tensor = [
        torch.tensor(data, requires_grad = True)
        for data in primary_rotations
    ]
    root_to_end_offset_tensor = [
        torch.tensor(data, requires_grad = True)
        for data in root_to_end_offset
    ]
    target_pos_tensor = torch.tensor(target_pos, requires_grad = True)
    
    for epcoh in range(epochs):
        # forward kinematics
        root_to_end_positions_tensor, root_to_end_orientations_tensor = forward_kinematics(
            root_positions_tensor = root_position_not_change_tensor,
            root_to_end_offset_tensor = root_to_end_offset_tensor,
            root_to_end_rotations_tensor = root_to_end_rotations_tensor
        )
        optimizer_target = torch.norm(
            root_to_end_positions_tensor[-1] - target_pos_tensor
        )
        optimizer_target.backward()
        
        print("epoch : {}, optimizer_target : {}", epcoh, optimizer_target.item())
        
        # calculate every rotations grad
        for i in range(num_joints):
            if root_to_end_rotations_tensor[i].grad is not None:
                print("grad of root_to_end_rotations_tensor[{}] : {}".format(i, root_to_end_rotations_tensor[i].grad))
                temp = root_to_end_rotations_tensor[i] - learning_rate * \
                    root_to_end_rotations_tensor[i].grad
                root_to_end_rotations_tensor[i] = temp
        
        if optimizer_target.item() < threshold:
            break
    
    # calculate the final position and orientation
    final_positions, final_orientations = forward_kinematics(
            root_positions_tensor = root_position_not_change_tensor,
            root_to_end_offset_tensor = root_to_end_offset_tensor,
            root_to_end_rotations_tensor = root_to_end_rotations_tensor
        )
    
    # return the final position and orientation -> list
    return final_positions, final_orientations

# %%
final_positions, final_orientation = inverse_kinematics_2(
    bone_tree = bone_tree_T_pos,
    path_info = path_info,
    target_pos = target_pos
)
# Out:
# epoch : {}, optimizer_target : {} 0 1.4413314028463158
# epoch : {}, optimizer_target : {} 1 1.4413314028463158
# epoch : {}, optimizer_target : {} 2 1.4413314028463158
# epoch : {}, optimizer_target : {} 3 1.4413314028463158
# epoch : {}, optimizer_target : {} 4 1.4413314028463158
# epoch : {}, optimizer_target : {} 5 1.4413314028463158
# epoch : {}, optimizer_target : {} 6 1.4413314028463158
# epoch : {}, optimizer_target : {} 7 1.4413314028463158
# epoch : {}, optimizer_target : {} 8 1.4413314028463158
# epoch : {}, optimizer_target : {} 9 1.4413314028463158
# epoch : {}, optimizer_target : {} 10 1.4413314028463158
# epoch : {}, optimizer_target : {} 11 1.4413314028463158
# epoch : {}, optimizer_target : {} 12 1.4413314028463158
# epoch : {}, optimizer_target : {} 13 1.4413314028463158
# epoch : {}, optimizer_target : {} 14 1.4413314028463158
# epoch : {}, optimizer_target : {} 15 1.4413314028463158
# epoch : {}, optimizer_target : {} 16 1.4413314028463158
# epoch : {}, optimizer_target : {} 17 1.4413314028463158
# epoch : {}, optimizer_target : {} 18 1.4413314028463158
# epoch : {}, optimizer_target : {} 19 1.4413314028463158
# epoch : {}, optimizer_target : {} 20 1.4413314028463158
# epoch : {}, optimizer_target : {} 21 1.4413314028463158
# epoch : {}, optimizer_target : {} 22 1.4413314028463158
# epoch : {}, optimizer_target : {} 23 1.4413314028463158
# epoch : {}, optimizer_target : {} 24 1.4413314028463158
# epoch : {}, optimizer_target : {} 25 1.4413314028463158
# epoch : {}, optimizer_target : {} 26 1.4413314028463158
# epoch : {}, optimizer_target : {} 27 1.4413314028463158
# epoch : {}, optimizer_target : {} 28 1.4413314028463158
# epoch : {}, optimizer_target : {} 29 1.4413314028463158
# epoch : {}, optimizer_target : {} 30 1.4413314028463158
# epoch : {}, optimizer_target : {} 31 1.4413314028463158
# epoch : {}, optimizer_target : {} 32 1.4413314028463158
# epoch : {}, optimizer_target : {} 33 1.4413314028463158
# epoch : {}, optimizer_target : {} 34 1.4413314028463158
# epoch : {}, optimizer_target : {} 35 1.4413314028463158
# epoch : {}, optimizer_target : {} 36 1.4413314028463158
# epoch : {}, optimizer_target : {} 37 1.4413314028463158
# epoch : {}, optimizer_target : {} 38 1.4413314028463158
# epoch : {}, optimizer_target : {} 39 1.4413314028463158
# epoch : {}, optimizer_target : {} 40 1.4413314028463158
# epoch : {}, optimizer_target : {} 41 1.4413314028463158
# epoch : {}, optimizer_target : {} 42 1.4413314028463158
# epoch : {}, optimizer_target : {} 43 1.4413314028463158
# epoch : {}, optimizer_target : {} 44 1.4413314028463158
# epoch : {}, optimizer_target : {} 45 1.4413314028463158
# epoch : {}, optimizer_target : {} 46 1.4413314028463158
# epoch : {}, optimizer_target : {} 47 1.4413314028463158
# epoch : {}, optimizer_target : {} 48 1.4413314028463158
# epoch : {}, optimizer_target : {} 49 1.4413314028463158
# epoch : {}, optimizer_target : {} 50 1.4413314028463158
# epoch : {}, optimizer_target : {} 51 1.4413314028463158
# epoch : {}, optimizer_target : {} 52 1.4413314028463158
# epoch : {}, optimizer_target : {} 53 1.4413314028463158
# epoch : {}, optimizer_target : {} 54 1.4413314028463158
# epoch : {}, optimizer_target : {} 55 1.4413314028463158
# epoch : {}, optimizer_target : {} 56 1.4413314028463158
# epoch : {}, optimizer_target : {} 57 1.4413314028463158
# epoch : {}, optimizer_target : {} 58 1.4413314028463158
# epoch : {}, optimizer_target : {} 59 1.4413314028463158
# epoch : {}, optimizer_target : {} 60 1.4413314028463158
# epoch : {}, optimizer_target : {} 61 1.4413314028463158
# epoch : {}, optimizer_target : {} 62 1.4413314028463158
# epoch : {}, optimizer_target : {} 63 1.4413314028463158
# epoch : {}, optimizer_target : {} 64 1.4413314028463158
# epoch : {}, optimizer_target : {} 65 1.4413314028463158
# epoch : {}, optimizer_target : {} 66 1.4413314028463158
# epoch : {}, optimizer_target : {} 67 1.4413314028463158
# epoch : {}, optimizer_target : {} 68 1.4413314028463158
# epoch : {}, optimizer_target : {} 69 1.4413314028463158
# epoch : {}, optimizer_target : {} 70 1.4413314028463158
# epoch : {}, optimizer_target : {} 71 1.4413314028463158
# epoch : {}, optimizer_target : {} 72 1.4413314028463158
# epoch : {}, optimizer_target : {} 73 1.4413314028463158
# epoch : {}, optimizer_target : {} 74 1.4413314028463158
# epoch : {}, optimizer_target : {} 75 1.4413314028463158
# epoch : {}, optimizer_target : {} 76 1.4413314028463158
# epoch : {}, optimizer_target : {} 77 1.4413314028463158
# epoch : {}, optimizer_target : {} 78 1.4413314028463158
# epoch : {}, optimizer_target : {} 79 1.4413314028463158
# epoch : {}, optimizer_target : {} 80 1.4413314028463158
# epoch : {}, optimizer_target : {} 81 1.4413314028463158
# epoch : {}, optimizer_target : {} 82 1.4413314028463158
# epoch : {}, optimizer_target : {} 83 1.4413314028463158
# epoch : {}, optimizer_target : {} 84 1.4413314028463158
# epoch : {}, optimizer_target : {} 85 1.4413314028463158
# epoch : {}, optimizer_target : {} 86 1.4413314028463158
# epoch : {}, optimizer_target : {} 87 1.4413314028463158
# epoch : {}, optimizer_target : {} 88 1.4413314028463158
# epoch : {}, optimizer_target : {} 89 1.4413314028463158
# epoch : {}, optimizer_target : {} 90 1.4413314028463158
# epoch : {}, optimizer_target : {} 91 1.4413314028463158
# epoch : {}, optimizer_target : {} 92 1.4413314028463158
# epoch : {}, optimizer_target : {} 93 1.4413314028463158
# epoch : {}, optimizer_target : {} 94 1.4413314028463158
# epoch : {}, optimizer_target : {} 95 1.4413314028463158
# epoch : {}, optimizer_target : {} 96 1.4413314028463158
# epoch : {}, optimizer_target : {} 97 1.4413314028463158
# epoch : {}, optimizer_target : {} 98 1.4413314028463158
# epoch : {}, optimizer_target : {} 99 1.4413314028463158
# epoch : {}, optimizer_target : {} 100 1.4413314028463158
# epoch : {}, optimizer_target : {} 101 1.4413314028463158
# epoch : {}, optimizer_target : {} 102 1.4413314028463158
# epoch : {}, optimizer_target : {} 103 1.4413314028463158
# epoch : {}, optimizer_target : {} 104 1.4413314028463158
# epoch : {}, optimizer_target : {} 105 1.4413314028463158
# epoch : {}, optimizer_target : {} 106 1.4413314028463158
# epoch : {}, optimizer_target : {} 107 1.4413314028463158
# epoch : {}, optimizer_target : {} 108 1.4413314028463158
# epoch : {}, optimizer_target : {} 109 1.4413314028463158
# epoch : {}, optimizer_target : {} 110 1.4413314028463158
# epoch : {}, optimizer_target : {} 111 1.4413314028463158
# epoch : {}, optimizer_target : {} 112 1.4413314028463158
# epoch : {}, optimizer_target : {} 113 1.4413314028463158
# epoch : {}, optimizer_target : {} 114 1.4413314028463158
# epoch : {}, optimizer_target : {} 115 1.4413314028463158
# epoch : {}, optimizer_target : {} 116 1.4413314028463158
# epoch : {}, optimizer_target : {} 117 1.4413314028463158
# epoch : {}, optimizer_target : {} 118 1.4413314028463158
# epoch : {}, optimizer_target : {} 119 1.4413314028463158
# epoch : {}, optimizer_target : {} 120 1.4413314028463158
# epoch : {}, optimizer_target : {} 121 1.4413314028463158
# epoch : {}, optimizer_target : {} 122 1.4413314028463158
# epoch : {}, optimizer_target : {} 123 1.4413314028463158
# epoch : {}, optimizer_target : {} 124 1.4413314028463158
# epoch : {}, optimizer_target : {} 125 1.4413314028463158
# epoch : {}, optimizer_target : {} 126 1.4413314028463158
# epoch : {}, optimizer_target : {} 127 1.4413314028463158
# epoch : {}, optimizer_target : {} 128 1.4413314028463158
# epoch : {}, optimizer_target : {} 129 1.4413314028463158
# epoch : {}, optimizer_target : {} 130 1.4413314028463158
# epoch : {}, optimizer_target : {} 131 1.4413314028463158
# epoch : {}, optimizer_target : {} 132 1.4413314028463158
# epoch : {}, optimizer_target : {} 133 1.4413314028463158
# epoch : {}, optimizer_target : {} 134 1.4413314028463158
# epoch : {}, optimizer_target : {} 135 1.4413314028463158
# epoch : {}, optimizer_target : {} 136 1.4413314028463158
# epoch : {}, optimizer_target : {} 137 1.4413314028463158
# epoch : {}, optimizer_target : {} 138 1.4413314028463158
# epoch : {}, optimizer_target : {} 139 1.4413314028463158
# epoch : {}, optimizer_target : {} 140 1.4413314028463158
# epoch : {}, optimizer_target : {} 141 1.4413314028463158
# epoch : {}, optimizer_target : {} 142 1.4413314028463158
# epoch : {}, optimizer_target : {} 143 1.4413314028463158
# epoch : {}, optimizer_target : {} 144 1.4413314028463158
# epoch : {}, optimizer_target : {} 145 1.4413314028463158
# epoch : {}, optimizer_target : {} 146 1.4413314028463158
# epoch : {}, optimizer_target : {} 147 1.4413314028463158
# epoch : {}, optimizer_target : {} 148 1.4413314028463158
# epoch : {}, optimizer_target : {} 149 1.4413314028463158
# epoch : {}, optimizer_target : {} 150 1.4413314028463158
# epoch : {}, optimizer_target : {} 151 1.4413314028463158
# epoch : {}, optimizer_target : {} 152 1.4413314028463158
# epoch : {}, optimizer_target : {} 153 1.4413314028463158
# epoch : {}, optimizer_target : {} 154 1.4413314028463158
# epoch : {}, optimizer_target : {} 155 1.4413314028463158
# epoch : {}, optimizer_target : {} 156 1.4413314028463158
# epoch : {}, optimizer_target : {} 157 1.4413314028463158
# epoch : {}, optimizer_target : {} 158 1.4413314028463158
# epoch : {}, optimizer_target : {} 159 1.4413314028463158
# epoch : {}, optimizer_target : {} 160 1.4413314028463158
# epoch : {}, optimizer_target : {} 161 1.4413314028463158
# epoch : {}, optimizer_target : {} 162 1.4413314028463158
# epoch : {}, optimizer_target : {} 163 1.4413314028463158
# epoch : {}, optimizer_target : {} 164 1.4413314028463158
# epoch : {}, optimizer_target : {} 165 1.4413314028463158
# epoch : {}, optimizer_target : {} 166 1.4413314028463158
# epoch : {}, optimizer_target : {} 167 1.4413314028463158
# epoch : {}, optimizer_target : {} 168 1.4413314028463158
# epoch : {}, optimizer_target : {} 169 1.4413314028463158
# epoch : {}, optimizer_target : {} 170 1.4413314028463158
# epoch : {}, optimizer_target : {} 171 1.4413314028463158
# epoch : {}, optimizer_target : {} 172 1.4413314028463158
# epoch : {}, optimizer_target : {} 173 1.4413314028463158
# epoch : {}, optimizer_target : {} 174 1.4413314028463158
# epoch : {}, optimizer_target : {} 175 1.4413314028463158
# epoch : {}, optimizer_target : {} 176 1.4413314028463158
# epoch : {}, optimizer_target : {} 177 1.4413314028463158
# epoch : {}, optimizer_target : {} 178 1.4413314028463158
# epoch : {}, optimizer_target : {} 179 1.4413314028463158
# epoch : {}, optimizer_target : {} 180 1.4413314028463158
# epoch : {}, optimizer_target : {} 181 1.4413314028463158
# epoch : {}, optimizer_target : {} 182 1.4413314028463158
# epoch : {}, optimizer_target : {} 183 1.4413314028463158
# epoch : {}, optimizer_target : {} 184 1.4413314028463158
# epoch : {}, optimizer_target : {} 185 1.4413314028463158
# epoch : {}, optimizer_target : {} 186 1.4413314028463158
# epoch : {}, optimizer_target : {} 187 1.4413314028463158
# epoch : {}, optimizer_target : {} 188 1.4413314028463158
# epoch : {}, optimizer_target : {} 189 1.4413314028463158
# epoch : {}, optimizer_target : {} 190 1.4413314028463158
# epoch : {}, optimizer_target : {} 191 1.4413314028463158
# epoch : {}, optimizer_target : {} 192 1.4413314028463158
# epoch : {}, optimizer_target : {} 193 1.4413314028463158
# epoch : {}, optimizer_target : {} 194 1.4413314028463158
# epoch : {}, optimizer_target : {} 195 1.4413314028463158
# epoch : {}, optimizer_target : {} 196 1.4413314028463158
# epoch : {}, optimizer_target : {} 197 1.4413314028463158
# epoch : {}, optimizer_target : {} 198 1.4413314028463158
# epoch : {}, optimizer_target : {} 199 1.4413314028463158
# epoch : {}, optimizer_target : {} 200 1.4413314028463158
# epoch : {}, optimizer_target : {} 201 1.4413314028463158
# epoch : {}, optimizer_target : {} 202 1.4413314028463158
# epoch : {}, optimizer_target : {} 203 1.4413314028463158
# epoch : {}, optimizer_target : {} 204 1.4413314028463158
# epoch : {}, optimizer_target : {} 205 1.4413314028463158
# epoch : {}, optimizer_target : {} 206 1.4413314028463158
# epoch : {}, optimizer_target : {} 207 1.4413314028463158
# epoch : {}, optimizer_target : {} 208 1.4413314028463158
# epoch : {}, optimizer_target : {} 209 1.4413314028463158
# epoch : {}, optimizer_target : {} 210 1.4413314028463158
# epoch : {}, optimizer_target : {} 211 1.4413314028463158
# epoch : {}, optimizer_target : {} 212 1.4413314028463158
# epoch : {}, optimizer_target : {} 213 1.4413314028463158
# epoch : {}, optimizer_target : {} 214 1.4413314028463158
# epoch : {}, optimizer_target : {} 215 1.4413314028463158
# epoch : {}, optimizer_target : {} 216 1.4413314028463158
# epoch : {}, optimizer_target : {} 217 1.4413314028463158
# epoch : {}, optimizer_target : {} 218 1.4413314028463158
# epoch : {}, optimizer_target : {} 219 1.4413314028463158
# epoch : {}, optimizer_target : {} 220 1.4413314028463158
# epoch : {}, optimizer_target : {} 221 1.4413314028463158
# epoch : {}, optimizer_target : {} 222 1.4413314028463158
# epoch : {}, optimizer_target : {} 223 1.4413314028463158
# epoch : {}, optimizer_target : {} 224 1.4413314028463158
# epoch : {}, optimizer_target : {} 225 1.4413314028463158
# epoch : {}, optimizer_target : {} 226 1.4413314028463158
# epoch : {}, optimizer_target : {} 227 1.4413314028463158
# epoch : {}, optimizer_target : {} 228 1.4413314028463158
# epoch : {}, optimizer_target : {} 229 1.4413314028463158
# epoch : {}, optimizer_target : {} 230 1.4413314028463158
# epoch : {}, optimizer_target : {} 231 1.4413314028463158
# epoch : {}, optimizer_target : {} 232 1.4413314028463158
# epoch : {}, optimizer_target : {} 233 1.4413314028463158
# epoch : {}, optimizer_target : {} 234 1.4413314028463158
# epoch : {}, optimizer_target : {} 235 1.4413314028463158
# epoch : {}, optimizer_target : {} 236 1.4413314028463158
# epoch : {}, optimizer_target : {} 237 1.4413314028463158
# epoch : {}, optimizer_target : {} 238 1.4413314028463158
# epoch : {}, optimizer_target : {} 239 1.4413314028463158
# epoch : {}, optimizer_target : {} 240 1.4413314028463158
# epoch : {}, optimizer_target : {} 241 1.4413314028463158
# epoch : {}, optimizer_target : {} 242 1.4413314028463158
# epoch : {}, optimizer_target : {} 243 1.4413314028463158
# epoch : {}, optimizer_target : {} 244 1.4413314028463158
# epoch : {}, optimizer_target : {} 245 1.4413314028463158
# epoch : {}, optimizer_target : {} 246 1.4413314028463158
# epoch : {}, optimizer_target : {} 247 1.4413314028463158
# epoch : {}, optimizer_target : {} 248 1.4413314028463158
# epoch : {}, optimizer_target : {} 249 1.4413314028463158
# epoch : {}, optimizer_target : {} 250 1.4413314028463158
# epoch : {}, optimizer_target : {} 251 1.4413314028463158
# epoch : {}, optimizer_target : {} 252 1.4413314028463158
# epoch : {}, optimizer_target : {} 253 1.4413314028463158
# epoch : {}, optimizer_target : {} 254 1.4413314028463158
# epoch : {}, optimizer_target : {} 255 1.4413314028463158
# epoch : {}, optimizer_target : {} 256 1.4413314028463158
# epoch : {}, optimizer_target : {} 257 1.4413314028463158
# epoch : {}, optimizer_target : {} 258 1.4413314028463158
# epoch : {}, optimizer_target : {} 259 1.4413314028463158
# epoch : {}, optimizer_target : {} 260 1.4413314028463158
# epoch : {}, optimizer_target : {} 261 1.4413314028463158
# epoch : {}, optimizer_target : {} 262 1.4413314028463158
# epoch : {}, optimizer_target : {} 263 1.4413314028463158
# epoch : {}, optimizer_target : {} 264 1.4413314028463158
# epoch : {}, optimizer_target : {} 265 1.4413314028463158
# epoch : {}, optimizer_target : {} 266 1.4413314028463158
# epoch : {}, optimizer_target : {} 267 1.4413314028463158
# epoch : {}, optimizer_target : {} 268 1.4413314028463158
# epoch : {}, optimizer_target : {} 269 1.4413314028463158
# epoch : {}, optimizer_target : {} 270 1.4413314028463158
# epoch : {}, optimizer_target : {} 271 1.4413314028463158
# epoch : {}, optimizer_target : {} 272 1.4413314028463158
# epoch : {}, optimizer_target : {} 273 1.4413314028463158
# epoch : {}, optimizer_target : {} 274 1.4413314028463158
# epoch : {}, optimizer_target : {} 275 1.4413314028463158
# epoch : {}, optimizer_target : {} 276 1.4413314028463158
# epoch : {}, optimizer_target : {} 277 1.4413314028463158
# epoch : {}, optimizer_target : {} 278 1.4413314028463158
# epoch : {}, optimizer_target : {} 279 1.4413314028463158
# epoch : {}, optimizer_target : {} 280 1.4413314028463158
# epoch : {}, optimizer_target : {} 281 1.4413314028463158
# epoch : {}, optimizer_target : {} 282 1.4413314028463158
# epoch : {}, optimizer_target : {} 283 1.4413314028463158
# epoch : {}, optimizer_target : {} 284 1.4413314028463158
# epoch : {}, optimizer_target : {} 285 1.4413314028463158
# epoch : {}, optimizer_target : {} 286 1.4413314028463158
# epoch : {}, optimizer_target : {} 287 1.4413314028463158
# epoch : {}, optimizer_target : {} 288 1.4413314028463158
# epoch : {}, optimizer_target : {} 289 1.4413314028463158
# epoch : {}, optimizer_target : {} 290 1.4413314028463158
# epoch : {}, optimizer_target : {} 291 1.4413314028463158
# epoch : {}, optimizer_target : {} 292 1.4413314028463158
# epoch : {}, optimizer_target : {} 293 1.4413314028463158
# epoch : {}, optimizer_target : {} 294 1.4413314028463158
# epoch : {}, optimizer_target : {} 295 1.4413314028463158
# epoch : {}, optimizer_target : {} 296 1.4413314028463158
# epoch : {}, optimizer_target : {} 297 1.4413314028463158
# epoch : {}, optimizer_target : {} 298 1.4413314028463158
# epoch : {}, optimizer_target : {} 299 1.4413314028463158
# epoch : {}, optimizer_target : {} 300 1.4413314028463158
# epoch : {}, optimizer_target : {} 301 1.4413314028463158
# epoch : {}, optimizer_target : {} 302 1.4413314028463158
# epoch : {}, optimizer_target : {} 303 1.4413314028463158
# epoch : {}, optimizer_target : {} 304 1.4413314028463158
# epoch : {}, optimizer_target : {} 305 1.4413314028463158
# epoch : {}, optimizer_target : {} 306 1.4413314028463158
# epoch : {}, optimizer_target : {} 307 1.4413314028463158
# epoch : {}, optimizer_target : {} 308 1.4413314028463158
# epoch : {}, optimizer_target : {} 309 1.4413314028463158
# epoch : {}, optimizer_target : {} 310 1.4413314028463158
# epoch : {}, optimizer_target : {} 311 1.4413314028463158
# epoch : {}, optimizer_target : {} 312 1.4413314028463158
# epoch : {}, optimizer_target : {} 313 1.4413314028463158
# epoch : {}, optimizer_target : {} 314 1.4413314028463158
# epoch : {}, optimizer_target : {} 315 1.4413314028463158
# epoch : {}, optimizer_target : {} 316 1.4413314028463158
# epoch : {}, optimizer_target : {} 317 1.4413314028463158
# epoch : {}, optimizer_target : {} 318 1.4413314028463158
# epoch : {}, optimizer_target : {} 319 1.4413314028463158
# epoch : {}, optimizer_target : {} 320 1.4413314028463158
# epoch : {}, optimizer_target : {} 321 1.4413314028463158
# epoch : {}, optimizer_target : {} 322 1.4413314028463158
# epoch : {}, optimizer_target : {} 323 1.4413314028463158
# epoch : {}, optimizer_target : {} 324 1.4413314028463158
# epoch : {}, optimizer_target : {} 325 1.4413314028463158
# epoch : {}, optimizer_target : {} 326 1.4413314028463158
# epoch : {}, optimizer_target : {} 327 1.4413314028463158
# epoch : {}, optimizer_target : {} 328 1.4413314028463158
# epoch : {}, optimizer_target : {} 329 1.4413314028463158
# epoch : {}, optimizer_target : {} 330 1.4413314028463158
# epoch : {}, optimizer_target : {} 331 1.4413314028463158
# epoch : {}, optimizer_target : {} 332 1.4413314028463158
# epoch : {}, optimizer_target : {} 333 1.4413314028463158
# epoch : {}, optimizer_target : {} 334 1.4413314028463158
# epoch : {}, optimizer_target : {} 335 1.4413314028463158
# epoch : {}, optimizer_target : {} 336 1.4413314028463158
# epoch : {}, optimizer_target : {} 337 1.4413314028463158
# epoch : {}, optimizer_target : {} 338 1.4413314028463158
# epoch : {}, optimizer_target : {} 339 1.4413314028463158
# epoch : {}, optimizer_target : {} 340 1.4413314028463158
# epoch : {}, optimizer_target : {} 341 1.4413314028463158
# epoch : {}, optimizer_target : {} 342 1.4413314028463158
# epoch : {}, optimizer_target : {} 343 1.4413314028463158
# epoch : {}, optimizer_target : {} 344 1.4413314028463158
# epoch : {}, optimizer_target : {} 345 1.4413314028463158
# epoch : {}, optimizer_target : {} 346 1.4413314028463158
# epoch : {}, optimizer_target : {} 347 1.4413314028463158
# epoch : {}, optimizer_target : {} 348 1.4413314028463158
# epoch : {}, optimizer_target : {} 349 1.4413314028463158
# epoch : {}, optimizer_target : {} 350 1.4413314028463158
# epoch : {}, optimizer_target : {} 351 1.4413314028463158
# epoch : {}, optimizer_target : {} 352 1.4413314028463158
# epoch : {}, optimizer_target : {} 353 1.4413314028463158
# epoch : {}, optimizer_target : {} 354 1.4413314028463158
# epoch : {}, optimizer_target : {} 355 1.4413314028463158
# epoch : {}, optimizer_target : {} 356 1.4413314028463158
# epoch : {}, optimizer_target : {} 357 1.4413314028463158
# epoch : {}, optimizer_target : {} 358 1.4413314028463158
# epoch : {}, optimizer_target : {} 359 1.4413314028463158
# epoch : {}, optimizer_target : {} 360 1.4413314028463158
# epoch : {}, optimizer_target : {} 361 1.4413314028463158
# epoch : {}, optimizer_target : {} 362 1.4413314028463158
# epoch : {}, optimizer_target : {} 363 1.4413314028463158
# epoch : {}, optimizer_target : {} 364 1.4413314028463158
# epoch : {}, optimizer_target : {} 365 1.4413314028463158
# epoch : {}, optimizer_target : {} 366 1.4413314028463158
# epoch : {}, optimizer_target : {} 367 1.4413314028463158
# epoch : {}, optimizer_target : {} 368 1.4413314028463158
# epoch : {}, optimizer_target : {} 369 1.4413314028463158
# epoch : {}, optimizer_target : {} 370 1.4413314028463158
# epoch : {}, optimizer_target : {} 371 1.4413314028463158
# epoch : {}, optimizer_target : {} 372 1.4413314028463158
# epoch : {}, optimizer_target : {} 373 1.4413314028463158
# epoch : {}, optimizer_target : {} 374 1.4413314028463158
# epoch : {}, optimizer_target : {} 375 1.4413314028463158
# epoch : {}, optimizer_target : {} 376 1.4413314028463158
# epoch : {}, optimizer_target : {} 377 1.4413314028463158
# epoch : {}, optimizer_target : {} 378 1.4413314028463158
# epoch : {}, optimizer_target : {} 379 1.4413314028463158
# epoch : {}, optimizer_target : {} 380 1.4413314028463158
# epoch : {}, optimizer_target : {} 381 1.4413314028463158
# epoch : {}, optimizer_target : {} 382 1.4413314028463158
# epoch : {}, optimizer_target : {} 383 1.4413314028463158
# epoch : {}, optimizer_target : {} 384 1.4413314028463158
# epoch : {}, optimizer_target : {} 385 1.4413314028463158
# epoch : {}, optimizer_target : {} 386 1.4413314028463158
# epoch : {}, optimizer_target : {} 387 1.4413314028463158
# epoch : {}, optimizer_target : {} 388 1.4413314028463158
# epoch : {}, optimizer_target : {} 389 1.4413314028463158
# epoch : {}, optimizer_target : {} 390 1.4413314028463158
# epoch : {}, optimizer_target : {} 391 1.4413314028463158
# epoch : {}, optimizer_target : {} 392 1.4413314028463158
# epoch : {}, optimizer_target : {} 393 1.4413314028463158
# epoch : {}, optimizer_target : {} 394 1.4413314028463158
# epoch : {}, optimizer_target : {} 395 1.4413314028463158
# epoch : {}, optimizer_target : {} 396 1.4413314028463158
# epoch : {}, optimizer_target : {} 397 1.4413314028463158
# epoch : {}, optimizer_target : {} 398 1.4413314028463158
# epoch : {}, optimizer_target : {} 399 1.4413314028463158
# epoch : {}, optimizer_target : {} 400 1.4413314028463158
# epoch : {}, optimizer_target : {} 401 1.4413314028463158
# epoch : {}, optimizer_target : {} 402 1.4413314028463158
# epoch : {}, optimizer_target : {} 403 1.4413314028463158
# epoch : {}, optimizer_target : {} 404 1.4413314028463158
# epoch : {}, optimizer_target : {} 405 1.4413314028463158
# epoch : {}, optimizer_target : {} 406 1.4413314028463158
# epoch : {}, optimizer_target : {} 407 1.4413314028463158
# epoch : {}, optimizer_target : {} 408 1.4413314028463158
# epoch : {}, optimizer_target : {} 409 1.4413314028463158
# epoch : {}, optimizer_target : {} 410 1.4413314028463158
# epoch : {}, optimizer_target : {} 411 1.4413314028463158
# epoch : {}, optimizer_target : {} 412 1.4413314028463158
# epoch : {}, optimizer_target : {} 413 1.4413314028463158
# epoch : {}, optimizer_target : {} 414 1.4413314028463158
# epoch : {}, optimizer_target : {} 415 1.4413314028463158
# epoch : {}, optimizer_target : {} 416 1.4413314028463158
# epoch : {}, optimizer_target : {} 417 1.4413314028463158
# epoch : {}, optimizer_target : {} 418 1.4413314028463158
# epoch : {}, optimizer_target : {} 419 1.4413314028463158
# epoch : {}, optimizer_target : {} 420 1.4413314028463158
# epoch : {}, optimizer_target : {} 421 1.4413314028463158
# epoch : {}, optimizer_target : {} 422 1.4413314028463158
# epoch : {}, optimizer_target : {} 423 1.4413314028463158
# epoch : {}, optimizer_target : {} 424 1.4413314028463158
# epoch : {}, optimizer_target : {} 425 1.4413314028463158
# epoch : {}, optimizer_target : {} 426 1.4413314028463158
# epoch : {}, optimizer_target : {} 427 1.4413314028463158
# epoch : {}, optimizer_target : {} 428 1.4413314028463158
# epoch : {}, optimizer_target : {} 429 1.4413314028463158
# epoch : {}, optimizer_target : {} 430 1.4413314028463158
# epoch : {}, optimizer_target : {} 431 1.4413314028463158
# epoch : {}, optimizer_target : {} 432 1.4413314028463158
# epoch : {}, optimizer_target : {} 433 1.4413314028463158
# epoch : {}, optimizer_target : {} 434 1.4413314028463158
# epoch : {}, optimizer_target : {} 435 1.4413314028463158
# epoch : {}, optimizer_target : {} 436 1.4413314028463158
# epoch : {}, optimizer_target : {} 437 1.4413314028463158
# epoch : {}, optimizer_target : {} 438 1.4413314028463158
# epoch : {}, optimizer_target : {} 439 1.4413314028463158
# epoch : {}, optimizer_target : {} 440 1.4413314028463158
# epoch : {}, optimizer_target : {} 441 1.4413314028463158
# epoch : {}, optimizer_target : {} 442 1.4413314028463158
# epoch : {}, optimizer_target : {} 443 1.4413314028463158
# epoch : {}, optimizer_target : {} 444 1.4413314028463158
# epoch : {}, optimizer_target : {} 445 1.4413314028463158
# epoch : {}, optimizer_target : {} 446 1.4413314028463158
# epoch : {}, optimizer_target : {} 447 1.4413314028463158
# epoch : {}, optimizer_target : {} 448 1.4413314028463158
# epoch : {}, optimizer_target : {} 449 1.4413314028463158
# epoch : {}, optimizer_target : {} 450 1.4413314028463158
# epoch : {}, optimizer_target : {} 451 1.4413314028463158
# epoch : {}, optimizer_target : {} 452 1.4413314028463158
# epoch : {}, optimizer_target : {} 453 1.4413314028463158
# epoch : {}, optimizer_target : {} 454 1.4413314028463158
# epoch : {}, optimizer_target : {} 455 1.4413314028463158
# epoch : {}, optimizer_target : {} 456 1.4413314028463158
# epoch : {}, optimizer_target : {} 457 1.4413314028463158
# epoch : {}, optimizer_target : {} 458 1.4413314028463158
# epoch : {}, optimizer_target : {} 459 1.4413314028463158
# epoch : {}, optimizer_target : {} 460 1.4413314028463158
# epoch : {}, optimizer_target : {} 461 1.4413314028463158
# epoch : {}, optimizer_target : {} 462 1.4413314028463158
# epoch : {}, optimizer_target : {} 463 1.4413314028463158
# epoch : {}, optimizer_target : {} 464 1.4413314028463158
# epoch : {}, optimizer_target : {} 465 1.4413314028463158
# epoch : {}, optimizer_target : {} 466 1.4413314028463158
# epoch : {}, optimizer_target : {} 467 1.4413314028463158
# epoch : {}, optimizer_target : {} 468 1.4413314028463158
# epoch : {}, optimizer_target : {} 469 1.4413314028463158
# epoch : {}, optimizer_target : {} 470 1.4413314028463158
# epoch : {}, optimizer_target : {} 471 1.4413314028463158
# epoch : {}, optimizer_target : {} 472 1.4413314028463158
# epoch : {}, optimizer_target : {} 473 1.4413314028463158
# epoch : {}, optimizer_target : {} 474 1.4413314028463158
# epoch : {}, optimizer_target : {} 475 1.4413314028463158
# epoch : {}, optimizer_target : {} 476 1.4413314028463158
# epoch : {}, optimizer_target : {} 477 1.4413314028463158
# epoch : {}, optimizer_target : {} 478 1.4413314028463158
# epoch : {}, optimizer_target : {} 479 1.4413314028463158
# epoch : {}, optimizer_target : {} 480 1.4413314028463158
# epoch : {}, optimizer_target : {} 481 1.4413314028463158
# epoch : {}, optimizer_target : {} 482 1.4413314028463158
# epoch : {}, optimizer_target : {} 483 1.4413314028463158
# epoch : {}, optimizer_target : {} 484 1.4413314028463158
# epoch : {}, optimizer_target : {} 485 1.4413314028463158
# epoch : {}, optimizer_target : {} 486 1.4413314028463158
# epoch : {}, optimizer_target : {} 487 1.4413314028463158
# epoch : {}, optimizer_target : {} 488 1.4413314028463158
# epoch : {}, optimizer_target : {} 489 1.4413314028463158
# epoch : {}, optimizer_target : {} 490 1.4413314028463158
# epoch : {}, optimizer_target : {} 491 1.4413314028463158
# epoch : {}, optimizer_target : {} 492 1.4413314028463158
# epoch : {}, optimizer_target : {} 493 1.4413314028463158
# epoch : {}, optimizer_target : {} 494 1.4413314028463158
# epoch : {}, optimizer_target : {} 495 1.4413314028463158
# epoch : {}, optimizer_target : {} 496 1.4413314028463158
# epoch : {}, optimizer_target : {} 497 1.4413314028463158
# epoch : {}, optimizer_target : {} 498 1.4413314028463158
# epoch : {}, optimizer_target : {} 499 1.4413314028463158
# epoch : {}, optimizer_target : {} 500 1.4413314028463158
# epoch : {}, optimizer_target : {} 501 1.4413314028463158
# epoch : {}, optimizer_target : {} 502 1.4413314028463158
# epoch : {}, optimizer_target : {} 503 1.4413314028463158
# epoch : {}, optimizer_target : {} 504 1.4413314028463158
# epoch : {}, optimizer_target : {} 505 1.4413314028463158
# epoch : {}, optimizer_target : {} 506 1.4413314028463158
# epoch : {}, optimizer_target : {} 507 1.4413314028463158
# epoch : {}, optimizer_target : {} 508 1.4413314028463158
# epoch : {}, optimizer_target : {} 509 1.4413314028463158
# epoch : {}, optimizer_target : {} 510 1.4413314028463158
# epoch : {}, optimizer_target : {} 511 1.4413314028463158
# epoch : {}, optimizer_target : {} 512 1.4413314028463158
# epoch : {}, optimizer_target : {} 513 1.4413314028463158
# epoch : {}, optimizer_target : {} 514 1.4413314028463158
# epoch : {}, optimizer_target : {} 515 1.4413314028463158
# epoch : {}, optimizer_target : {} 516 1.4413314028463158
# epoch : {}, optimizer_target : {} 517 1.4413314028463158
# epoch : {}, optimizer_target : {} 518 1.4413314028463158
# epoch : {}, optimizer_target : {} 519 1.4413314028463158
# epoch : {}, optimizer_target : {} 520 1.4413314028463158
# epoch : {}, optimizer_target : {} 521 1.4413314028463158
# epoch : {}, optimizer_target : {} 522 1.4413314028463158
# epoch : {}, optimizer_target : {} 523 1.4413314028463158
# epoch : {}, optimizer_target : {} 524 1.4413314028463158
# epoch : {}, optimizer_target : {} 525 1.4413314028463158
# epoch : {}, optimizer_target : {} 526 1.4413314028463158
# epoch : {}, optimizer_target : {} 527 1.4413314028463158
# epoch : {}, optimizer_target : {} 528 1.4413314028463158
# epoch : {}, optimizer_target : {} 529 1.4413314028463158
# epoch : {}, optimizer_target : {} 530 1.4413314028463158
# epoch : {}, optimizer_target : {} 531 1.4413314028463158
# epoch : {}, optimizer_target : {} 532 1.4413314028463158
# epoch : {}, optimizer_target : {} 533 1.4413314028463158
# epoch : {}, optimizer_target : {} 534 1.4413314028463158
# epoch : {}, optimizer_target : {} 535 1.4413314028463158
# epoch : {}, optimizer_target : {} 536 1.4413314028463158
# epoch : {}, optimizer_target : {} 537 1.4413314028463158
# epoch : {}, optimizer_target : {} 538 1.4413314028463158
# epoch : {}, optimizer_target : {} 539 1.4413314028463158
# epoch : {}, optimizer_target : {} 540 1.4413314028463158
# epoch : {}, optimizer_target : {} 541 1.4413314028463158
# epoch : {}, optimizer_target : {} 542 1.4413314028463158
# epoch : {}, optimizer_target : {} 543 1.4413314028463158
# epoch : {}, optimizer_target : {} 544 1.4413314028463158
# epoch : {}, optimizer_target : {} 545 1.4413314028463158
# epoch : {}, optimizer_target : {} 546 1.4413314028463158
# epoch : {}, optimizer_target : {} 547 1.4413314028463158
# epoch : {}, optimizer_target : {} 548 1.4413314028463158
# epoch : {}, optimizer_target : {} 549 1.4413314028463158
# epoch : {}, optimizer_target : {} 550 1.4413314028463158
# epoch : {}, optimizer_target : {} 551 1.4413314028463158
# epoch : {}, optimizer_target : {} 552 1.4413314028463158
# epoch : {}, optimizer_target : {} 553 1.4413314028463158
# epoch : {}, optimizer_target : {} 554 1.4413314028463158
# epoch : {}, optimizer_target : {} 555 1.4413314028463158
# epoch : {}, optimizer_target : {} 556 1.4413314028463158
# epoch : {}, optimizer_target : {} 557 1.4413314028463158
# epoch : {}, optimizer_target : {} 558 1.4413314028463158
# epoch : {}, optimizer_target : {} 559 1.4413314028463158
# epoch : {}, optimizer_target : {} 560 1.4413314028463158
# epoch : {}, optimizer_target : {} 561 1.4413314028463158
# epoch : {}, optimizer_target : {} 562 1.4413314028463158
# epoch : {}, optimizer_target : {} 563 1.4413314028463158
# epoch : {}, optimizer_target : {} 564 1.4413314028463158
# epoch : {}, optimizer_target : {} 565 1.4413314028463158
# epoch : {}, optimizer_target : {} 566 1.4413314028463158
# epoch : {}, optimizer_target : {} 567 1.4413314028463158
# epoch : {}, optimizer_target : {} 568 1.4413314028463158
# epoch : {}, optimizer_target : {} 569 1.4413314028463158
# epoch : {}, optimizer_target : {} 570 1.4413314028463158
# epoch : {}, optimizer_target : {} 571 1.4413314028463158
# epoch : {}, optimizer_target : {} 572 1.4413314028463158
# epoch : {}, optimizer_target : {} 573 1.4413314028463158
# epoch : {}, optimizer_target : {} 574 1.4413314028463158
# epoch : {}, optimizer_target : {} 575 1.4413314028463158
# epoch : {}, optimizer_target : {} 576 1.4413314028463158
# epoch : {}, optimizer_target : {} 577 1.4413314028463158
# epoch : {}, optimizer_target : {} 578 1.4413314028463158
# epoch : {}, optimizer_target : {} 579 1.4413314028463158
# epoch : {}, optimizer_target : {} 580 1.4413314028463158
# epoch : {}, optimizer_target : {} 581 1.4413314028463158
# epoch : {}, optimizer_target : {} 582 1.4413314028463158
# epoch : {}, optimizer_target : {} 583 1.4413314028463158
# epoch : {}, optimizer_target : {} 584 1.4413314028463158
# epoch : {}, optimizer_target : {} 585 1.4413314028463158
# epoch : {}, optimizer_target : {} 586 1.4413314028463158
# epoch : {}, optimizer_target : {} 587 1.4413314028463158
# epoch : {}, optimizer_target : {} 588 1.4413314028463158
# epoch : {}, optimizer_target : {} 589 1.4413314028463158
# epoch : {}, optimizer_target : {} 590 1.4413314028463158
# epoch : {}, optimizer_target : {} 591 1.4413314028463158
# epoch : {}, optimizer_target : {} 592 1.4413314028463158
# epoch : {}, optimizer_target : {} 593 1.4413314028463158
# epoch : {}, optimizer_target : {} 594 1.4413314028463158
# epoch : {}, optimizer_target : {} 595 1.4413314028463158
# epoch : {}, optimizer_target : {} 596 1.4413314028463158
# epoch : {}, optimizer_target : {} 597 1.4413314028463158
# epoch : {}, optimizer_target : {} 598 1.4413314028463158
# epoch : {}, optimizer_target : {} 599 1.4413314028463158
# epoch : {}, optimizer_target : {} 600 1.4413314028463158
# epoch : {}, optimizer_target : {} 601 1.4413314028463158
# epoch : {}, optimizer_target : {} 602 1.4413314028463158
# epoch : {}, optimizer_target : {} 603 1.4413314028463158
# epoch : {}, optimizer_target : {} 604 1.4413314028463158
# epoch : {}, optimizer_target : {} 605 1.4413314028463158
# epoch : {}, optimizer_target : {} 606 1.4413314028463158
# epoch : {}, optimizer_target : {} 607 1.4413314028463158
# epoch : {}, optimizer_target : {} 608 1.4413314028463158
# epoch : {}, optimizer_target : {} 609 1.4413314028463158
# epoch : {}, optimizer_target : {} 610 1.4413314028463158
# epoch : {}, optimizer_target : {} 611 1.4413314028463158
# epoch : {}, optimizer_target : {} 612 1.4413314028463158
# epoch : {}, optimizer_target : {} 613 1.4413314028463158
# epoch : {}, optimizer_target : {} 614 1.4413314028463158
# epoch : {}, optimizer_target : {} 615 1.4413314028463158
# epoch : {}, optimizer_target : {} 616 1.4413314028463158
# epoch : {}, optimizer_target : {} 617 1.4413314028463158
# epoch : {}, optimizer_target : {} 618 1.4413314028463158
# epoch : {}, optimizer_target : {} 619 1.4413314028463158
# epoch : {}, optimizer_target : {} 620 1.4413314028463158
# epoch : {}, optimizer_target : {} 621 1.4413314028463158
# epoch : {}, optimizer_target : {} 622 1.4413314028463158
# epoch : {}, optimizer_target : {} 623 1.4413314028463158
# epoch : {}, optimizer_target : {} 624 1.4413314028463158
# epoch : {}, optimizer_target : {} 625 1.4413314028463158
# epoch : {}, optimizer_target : {} 626 1.4413314028463158
# epoch : {}, optimizer_target : {} 627 1.4413314028463158
# epoch : {}, optimizer_target : {} 628 1.4413314028463158
# epoch : {}, optimizer_target : {} 629 1.4413314028463158
# epoch : {}, optimizer_target : {} 630 1.4413314028463158
# epoch : {}, optimizer_target : {} 631 1.4413314028463158
# epoch : {}, optimizer_target : {} 632 1.4413314028463158
# epoch : {}, optimizer_target : {} 633 1.4413314028463158
# epoch : {}, optimizer_target : {} 634 1.4413314028463158
# epoch : {}, optimizer_target : {} 635 1.4413314028463158
# epoch : {}, optimizer_target : {} 636 1.4413314028463158
# epoch : {}, optimizer_target : {} 637 1.4413314028463158
# epoch : {}, optimizer_target : {} 638 1.4413314028463158
# epoch : {}, optimizer_target : {} 639 1.4413314028463158
# epoch : {}, optimizer_target : {} 640 1.4413314028463158
# epoch : {}, optimizer_target : {} 641 1.4413314028463158
# epoch : {}, optimizer_target : {} 642 1.4413314028463158
# epoch : {}, optimizer_target : {} 643 1.4413314028463158
# epoch : {}, optimizer_target : {} 644 1.4413314028463158
# epoch : {}, optimizer_target : {} 645 1.4413314028463158
# epoch : {}, optimizer_target : {} 646 1.4413314028463158
# epoch : {}, optimizer_target : {} 647 1.4413314028463158
# epoch : {}, optimizer_target : {} 648 1.4413314028463158
# epoch : {}, optimizer_target : {} 649 1.4413314028463158
# epoch : {}, optimizer_target : {} 650 1.4413314028463158
# epoch : {}, optimizer_target : {} 651 1.4413314028463158
# epoch : {}, optimizer_target : {} 652 1.4413314028463158
# epoch : {}, optimizer_target : {} 653 1.4413314028463158
# epoch : {}, optimizer_target : {} 654 1.4413314028463158
# epoch : {}, optimizer_target : {} 655 1.4413314028463158
# epoch : {}, optimizer_target : {} 656 1.4413314028463158
# epoch : {}, optimizer_target : {} 657 1.4413314028463158
# epoch : {}, optimizer_target : {} 658 1.4413314028463158
# epoch : {}, optimizer_target : {} 659 1.4413314028463158
# epoch : {}, optimizer_target : {} 660 1.4413314028463158
# epoch : {}, optimizer_target : {} 661 1.4413314028463158
# epoch : {}, optimizer_target : {} 662 1.4413314028463158
# epoch : {}, optimizer_target : {} 663 1.4413314028463158
# epoch : {}, optimizer_target : {} 664 1.4413314028463158
# epoch : {}, optimizer_target : {} 665 1.4413314028463158
# epoch : {}, optimizer_target : {} 666 1.4413314028463158
# epoch : {}, optimizer_target : {} 667 1.4413314028463158
# epoch : {}, optimizer_target : {} 668 1.4413314028463158
# epoch : {}, optimizer_target : {} 669 1.4413314028463158
# epoch : {}, optimizer_target : {} 670 1.4413314028463158
# epoch : {}, optimizer_target : {} 671 1.4413314028463158
# epoch : {}, optimizer_target : {} 672 1.4413314028463158
# epoch : {}, optimizer_target : {} 673 1.4413314028463158
# epoch : {}, optimizer_target : {} 674 1.4413314028463158
# epoch : {}, optimizer_target : {} 675 1.4413314028463158
# epoch : {}, optimizer_target : {} 676 1.4413314028463158
# epoch : {}, optimizer_target : {} 677 1.4413314028463158
# epoch : {}, optimizer_target : {} 678 1.4413314028463158
# epoch : {}, optimizer_target : {} 679 1.4413314028463158
# epoch : {}, optimizer_target : {} 680 1.4413314028463158
# epoch : {}, optimizer_target : {} 681 1.4413314028463158
# epoch : {}, optimizer_target : {} 682 1.4413314028463158
# epoch : {}, optimizer_target : {} 683 1.4413314028463158
# epoch : {}, optimizer_target : {} 684 1.4413314028463158
# epoch : {}, optimizer_target : {} 685 1.4413314028463158
# epoch : {}, optimizer_target : {} 686 1.4413314028463158
# epoch : {}, optimizer_target : {} 687 1.4413314028463158
# epoch : {}, optimizer_target : {} 688 1.4413314028463158
# epoch : {}, optimizer_target : {} 689 1.4413314028463158
# epoch : {}, optimizer_target : {} 690 1.4413314028463158
# epoch : {}, optimizer_target : {} 691 1.4413314028463158
# epoch : {}, optimizer_target : {} 692 1.4413314028463158
# epoch : {}, optimizer_target : {} 693 1.4413314028463158
# epoch : {}, optimizer_target : {} 694 1.4413314028463158
# epoch : {}, optimizer_target : {} 695 1.4413314028463158
# epoch : {}, optimizer_target : {} 696 1.4413314028463158
# epoch : {}, optimizer_target : {} 697 1.4413314028463158
# epoch : {}, optimizer_target : {} 698 1.4413314028463158
# epoch : {}, optimizer_target : {} 699 1.4413314028463158
# epoch : {}, optimizer_target : {} 700 1.4413314028463158
# epoch : {}, optimizer_target : {} 701 1.4413314028463158
# epoch : {}, optimizer_target : {} 702 1.4413314028463158
# epoch : {}, optimizer_target : {} 703 1.4413314028463158
# epoch : {}, optimizer_target : {} 704 1.4413314028463158
# epoch : {}, optimizer_target : {} 705 1.4413314028463158
# epoch : {}, optimizer_target : {} 706 1.4413314028463158
# epoch : {}, optimizer_target : {} 707 1.4413314028463158
# epoch : {}, optimizer_target : {} 708 1.4413314028463158
# epoch : {}, optimizer_target : {} 709 1.4413314028463158
# epoch : {}, optimizer_target : {} 710 1.4413314028463158
# epoch : {}, optimizer_target : {} 711 1.4413314028463158
# epoch : {}, optimizer_target : {} 712 1.4413314028463158
# epoch : {}, optimizer_target : {} 713 1.4413314028463158
# epoch : {}, optimizer_target : {} 714 1.4413314028463158
# epoch : {}, optimizer_target : {} 715 1.4413314028463158
# epoch : {}, optimizer_target : {} 716 1.4413314028463158
# epoch : {}, optimizer_target : {} 717 1.4413314028463158
# epoch : {}, optimizer_target : {} 718 1.4413314028463158
# epoch : {}, optimizer_target : {} 719 1.4413314028463158
# epoch : {}, optimizer_target : {} 720 1.4413314028463158
# epoch : {}, optimizer_target : {} 721 1.4413314028463158
# epoch : {}, optimizer_target : {} 722 1.4413314028463158
# epoch : {}, optimizer_target : {} 723 1.4413314028463158
# epoch : {}, optimizer_target : {} 724 1.4413314028463158
# epoch : {}, optimizer_target : {} 725 1.4413314028463158
# epoch : {}, optimizer_target : {} 726 1.4413314028463158
# epoch : {}, optimizer_target : {} 727 1.4413314028463158
# epoch : {}, optimizer_target : {} 728 1.4413314028463158
# epoch : {}, optimizer_target : {} 729 1.4413314028463158
# epoch : {}, optimizer_target : {} 730 1.4413314028463158
# epoch : {}, optimizer_target : {} 731 1.4413314028463158
# epoch : {}, optimizer_target : {} 732 1.4413314028463158
# epoch : {}, optimizer_target : {} 733 1.4413314028463158
# epoch : {}, optimizer_target : {} 734 1.4413314028463158
# epoch : {}, optimizer_target : {} 735 1.4413314028463158
# epoch : {}, optimizer_target : {} 736 1.4413314028463158
# epoch : {}, optimizer_target : {} 737 1.4413314028463158
# epoch : {}, optimizer_target : {} 738 1.4413314028463158
# epoch : {}, optimizer_target : {} 739 1.4413314028463158
# epoch : {}, optimizer_target : {} 740 1.4413314028463158
# epoch : {}, optimizer_target : {} 741 1.4413314028463158
# epoch : {}, optimizer_target : {} 742 1.4413314028463158
# epoch : {}, optimizer_target : {} 743 1.4413314028463158
# epoch : {}, optimizer_target : {} 744 1.4413314028463158
# epoch : {}, optimizer_target : {} 745 1.4413314028463158
# epoch : {}, optimizer_target : {} 746 1.4413314028463158
# epoch : {}, optimizer_target : {} 747 1.4413314028463158
# epoch : {}, optimizer_target : {} 748 1.4413314028463158
# epoch : {}, optimizer_target : {} 749 1.4413314028463158
# epoch : {}, optimizer_target : {} 750 1.4413314028463158
# epoch : {}, optimizer_target : {} 751 1.4413314028463158
# epoch : {}, optimizer_target : {} 752 1.4413314028463158
# epoch : {}, optimizer_target : {} 753 1.4413314028463158
# epoch : {}, optimizer_target : {} 754 1.4413314028463158
# epoch : {}, optimizer_target : {} 755 1.4413314028463158
# epoch : {}, optimizer_target : {} 756 1.4413314028463158
# epoch : {}, optimizer_target : {} 757 1.4413314028463158
# epoch : {}, optimizer_target : {} 758 1.4413314028463158
# epoch : {}, optimizer_target : {} 759 1.4413314028463158
# epoch : {}, optimizer_target : {} 760 1.4413314028463158
# epoch : {}, optimizer_target : {} 761 1.4413314028463158
# epoch : {}, optimizer_target : {} 762 1.4413314028463158
# epoch : {}, optimizer_target : {} 763 1.4413314028463158
# epoch : {}, optimizer_target : {} 764 1.4413314028463158
# epoch : {}, optimizer_target : {} 765 1.4413314028463158
# epoch : {}, optimizer_target : {} 766 1.4413314028463158
# epoch : {}, optimizer_target : {} 767 1.4413314028463158
# epoch : {}, optimizer_target : {} 768 1.4413314028463158
# epoch : {}, optimizer_target : {} 769 1.4413314028463158
# epoch : {}, optimizer_target : {} 770 1.4413314028463158
# epoch : {}, optimizer_target : {} 771 1.4413314028463158
# epoch : {}, optimizer_target : {} 772 1.4413314028463158
# epoch : {}, optimizer_target : {} 773 1.4413314028463158
# epoch : {}, optimizer_target : {} 774 1.4413314028463158
# epoch : {}, optimizer_target : {} 775 1.4413314028463158
# epoch : {}, optimizer_target : {} 776 1.4413314028463158
# epoch : {}, optimizer_target : {} 777 1.4413314028463158
# epoch : {}, optimizer_target : {} 778 1.4413314028463158
# epoch : {}, optimizer_target : {} 779 1.4413314028463158
# epoch : {}, optimizer_target : {} 780 1.4413314028463158
# epoch : {}, optimizer_target : {} 781 1.4413314028463158
# epoch : {}, optimizer_target : {} 782 1.4413314028463158
# epoch : {}, optimizer_target : {} 783 1.4413314028463158
# epoch : {}, optimizer_target : {} 784 1.4413314028463158
# epoch : {}, optimizer_target : {} 785 1.4413314028463158
# epoch : {}, optimizer_target : {} 786 1.4413314028463158
# epoch : {}, optimizer_target : {} 787 1.4413314028463158
# epoch : {}, optimizer_target : {} 788 1.4413314028463158
# epoch : {}, optimizer_target : {} 789 1.4413314028463158
# epoch : {}, optimizer_target : {} 790 1.4413314028463158
# epoch : {}, optimizer_target : {} 791 1.4413314028463158
# epoch : {}, optimizer_target : {} 792 1.4413314028463158
# epoch : {}, optimizer_target : {} 793 1.4413314028463158
# epoch : {}, optimizer_target : {} 794 1.4413314028463158
# epoch : {}, optimizer_target : {} 795 1.4413314028463158
# epoch : {}, optimizer_target : {} 796 1.4413314028463158
# epoch : {}, optimizer_target : {} 797 1.4413314028463158
# epoch : {}, optimizer_target : {} 798 1.4413314028463158
# epoch : {}, optimizer_target : {} 799 1.4413314028463158
# epoch : {}, optimizer_target : {} 800 1.4413314028463158
# epoch : {}, optimizer_target : {} 801 1.4413314028463158
# epoch : {}, optimizer_target : {} 802 1.4413314028463158
# epoch : {}, optimizer_target : {} 803 1.4413314028463158
# epoch : {}, optimizer_target : {} 804 1.4413314028463158
# epoch : {}, optimizer_target : {} 805 1.4413314028463158
# epoch : {}, optimizer_target : {} 806 1.4413314028463158
# epoch : {}, optimizer_target : {} 807 1.4413314028463158
# epoch : {}, optimizer_target : {} 808 1.4413314028463158
# epoch : {}, optimizer_target : {} 809 1.4413314028463158
# epoch : {}, optimizer_target : {} 810 1.4413314028463158
# epoch : {}, optimizer_target : {} 811 1.4413314028463158
# epoch : {}, optimizer_target : {} 812 1.4413314028463158
# epoch : {}, optimizer_target : {} 813 1.4413314028463158
# epoch : {}, optimizer_target : {} 814 1.4413314028463158
# epoch : {}, optimizer_target : {} 815 1.4413314028463158
# epoch : {}, optimizer_target : {} 816 1.4413314028463158
# epoch : {}, optimizer_target : {} 817 1.4413314028463158
# epoch : {}, optimizer_target : {} 818 1.4413314028463158
# epoch : {}, optimizer_target : {} 819 1.4413314028463158
# epoch : {}, optimizer_target : {} 820 1.4413314028463158
# epoch : {}, optimizer_target : {} 821 1.4413314028463158
# epoch : {}, optimizer_target : {} 822 1.4413314028463158
# epoch : {}, optimizer_target : {} 823 1.4413314028463158
# epoch : {}, optimizer_target : {} 824 1.4413314028463158
# epoch : {}, optimizer_target : {} 825 1.4413314028463158
# epoch : {}, optimizer_target : {} 826 1.4413314028463158
# epoch : {}, optimizer_target : {} 827 1.4413314028463158
# epoch : {}, optimizer_target : {} 828 1.4413314028463158
# epoch : {}, optimizer_target : {} 829 1.4413314028463158
# epoch : {}, optimizer_target : {} 830 1.4413314028463158
# epoch : {}, optimizer_target : {} 831 1.4413314028463158
# epoch : {}, optimizer_target : {} 832 1.4413314028463158
# epoch : {}, optimizer_target : {} 833 1.4413314028463158
# epoch : {}, optimizer_target : {} 834 1.4413314028463158
# epoch : {}, optimizer_target : {} 835 1.4413314028463158
# epoch : {}, optimizer_target : {} 836 1.4413314028463158
# epoch : {}, optimizer_target : {} 837 1.4413314028463158
# epoch : {}, optimizer_target : {} 838 1.4413314028463158
# epoch : {}, optimizer_target : {} 839 1.4413314028463158
# epoch : {}, optimizer_target : {} 840 1.4413314028463158
# epoch : {}, optimizer_target : {} 841 1.4413314028463158
# epoch : {}, optimizer_target : {} 842 1.4413314028463158
# epoch : {}, optimizer_target : {} 843 1.4413314028463158
# epoch : {}, optimizer_target : {} 844 1.4413314028463158
# epoch : {}, optimizer_target : {} 845 1.4413314028463158
# epoch : {}, optimizer_target : {} 846 1.4413314028463158
# epoch : {}, optimizer_target : {} 847 1.4413314028463158
# epoch : {}, optimizer_target : {} 848 1.4413314028463158
# epoch : {}, optimizer_target : {} 849 1.4413314028463158
# epoch : {}, optimizer_target : {} 850 1.4413314028463158
# epoch : {}, optimizer_target : {} 851 1.4413314028463158
# epoch : {}, optimizer_target : {} 852 1.4413314028463158
# epoch : {}, optimizer_target : {} 853 1.4413314028463158
# epoch : {}, optimizer_target : {} 854 1.4413314028463158
# epoch : {}, optimizer_target : {} 855 1.4413314028463158
# epoch : {}, optimizer_target : {} 856 1.4413314028463158
# epoch : {}, optimizer_target : {} 857 1.4413314028463158
# epoch : {}, optimizer_target : {} 858 1.4413314028463158
# epoch : {}, optimizer_target : {} 859 1.4413314028463158
# epoch : {}, optimizer_target : {} 860 1.4413314028463158
# epoch : {}, optimizer_target : {} 861 1.4413314028463158
# epoch : {}, optimizer_target : {} 862 1.4413314028463158
# epoch : {}, optimizer_target : {} 863 1.4413314028463158
# epoch : {}, optimizer_target : {} 864 1.4413314028463158
# epoch : {}, optimizer_target : {} 865 1.4413314028463158
# epoch : {}, optimizer_target : {} 866 1.4413314028463158
# epoch : {}, optimizer_target : {} 867 1.4413314028463158
# epoch : {}, optimizer_target : {} 868 1.4413314028463158
# epoch : {}, optimizer_target : {} 869 1.4413314028463158
# epoch : {}, optimizer_target : {} 870 1.4413314028463158
# epoch : {}, optimizer_target : {} 871 1.4413314028463158
# epoch : {}, optimizer_target : {} 872 1.4413314028463158
# epoch : {}, optimizer_target : {} 873 1.4413314028463158
# epoch : {}, optimizer_target : {} 874 1.4413314028463158
# epoch : {}, optimizer_target : {} 875 1.4413314028463158
# epoch : {}, optimizer_target : {} 876 1.4413314028463158
# epoch : {}, optimizer_target : {} 877 1.4413314028463158
# epoch : {}, optimizer_target : {} 878 1.4413314028463158
# epoch : {}, optimizer_target : {} 879 1.4413314028463158
# epoch : {}, optimizer_target : {} 880 1.4413314028463158
# epoch : {}, optimizer_target : {} 881 1.4413314028463158
# epoch : {}, optimizer_target : {} 882 1.4413314028463158
# epoch : {}, optimizer_target : {} 883 1.4413314028463158
# epoch : {}, optimizer_target : {} 884 1.4413314028463158
# epoch : {}, optimizer_target : {} 885 1.4413314028463158
# epoch : {}, optimizer_target : {} 886 1.4413314028463158
# epoch : {}, optimizer_target : {} 887 1.4413314028463158
# epoch : {}, optimizer_target : {} 888 1.4413314028463158
# epoch : {}, optimizer_target : {} 889 1.4413314028463158
# epoch : {}, optimizer_target : {} 890 1.4413314028463158
# epoch : {}, optimizer_target : {} 891 1.4413314028463158
# epoch : {}, optimizer_target : {} 892 1.4413314028463158
# epoch : {}, optimizer_target : {} 893 1.4413314028463158
# epoch : {}, optimizer_target : {} 894 1.4413314028463158
# epoch : {}, optimizer_target : {} 895 1.4413314028463158
# epoch : {}, optimizer_target : {} 896 1.4413314028463158
# epoch : {}, optimizer_target : {} 897 1.4413314028463158
# epoch : {}, optimizer_target : {} 898 1.4413314028463158
# epoch : {}, optimizer_target : {} 899 1.4413314028463158
# epoch : {}, optimizer_target : {} 900 1.4413314028463158
# epoch : {}, optimizer_target : {} 901 1.4413314028463158
# epoch : {}, optimizer_target : {} 902 1.4413314028463158
# epoch : {}, optimizer_target : {} 903 1.4413314028463158
# epoch : {}, optimizer_target : {} 904 1.4413314028463158
# epoch : {}, optimizer_target : {} 905 1.4413314028463158
# epoch : {}, optimizer_target : {} 906 1.4413314028463158
# epoch : {}, optimizer_target : {} 907 1.4413314028463158
# epoch : {}, optimizer_target : {} 908 1.4413314028463158
# epoch : {}, optimizer_target : {} 909 1.4413314028463158
# epoch : {}, optimizer_target : {} 910 1.4413314028463158
# epoch : {}, optimizer_target : {} 911 1.4413314028463158
# epoch : {}, optimizer_target : {} 912 1.4413314028463158
# epoch : {}, optimizer_target : {} 913 1.4413314028463158
# epoch : {}, optimizer_target : {} 914 1.4413314028463158
# epoch : {}, optimizer_target : {} 915 1.4413314028463158
# epoch : {}, optimizer_target : {} 916 1.4413314028463158
# epoch : {}, optimizer_target : {} 917 1.4413314028463158
# epoch : {}, optimizer_target : {} 918 1.4413314028463158
# epoch : {}, optimizer_target : {} 919 1.4413314028463158
# epoch : {}, optimizer_target : {} 920 1.4413314028463158
# epoch : {}, optimizer_target : {} 921 1.4413314028463158
# epoch : {}, optimizer_target : {} 922 1.4413314028463158
# epoch : {}, optimizer_target : {} 923 1.4413314028463158
# epoch : {}, optimizer_target : {} 924 1.4413314028463158
# epoch : {}, optimizer_target : {} 925 1.4413314028463158
# epoch : {}, optimizer_target : {} 926 1.4413314028463158
# epoch : {}, optimizer_target : {} 927 1.4413314028463158
# epoch : {}, optimizer_target : {} 928 1.4413314028463158
# epoch : {}, optimizer_target : {} 929 1.4413314028463158
# epoch : {}, optimizer_target : {} 930 1.4413314028463158
# epoch : {}, optimizer_target : {} 931 1.4413314028463158
# epoch : {}, optimizer_target : {} 932 1.4413314028463158
# epoch : {}, optimizer_target : {} 933 1.4413314028463158
# epoch : {}, optimizer_target : {} 934 1.4413314028463158
# epoch : {}, optimizer_target : {} 935 1.4413314028463158
# epoch : {}, optimizer_target : {} 936 1.4413314028463158
# epoch : {}, optimizer_target : {} 937 1.4413314028463158
# epoch : {}, optimizer_target : {} 938 1.4413314028463158
# epoch : {}, optimizer_target : {} 939 1.4413314028463158
# epoch : {}, optimizer_target : {} 940 1.4413314028463158
# epoch : {}, optimizer_target : {} 941 1.4413314028463158
# epoch : {}, optimizer_target : {} 942 1.4413314028463158
# epoch : {}, optimizer_target : {} 943 1.4413314028463158
# epoch : {}, optimizer_target : {} 944 1.4413314028463158
# epoch : {}, optimizer_target : {} 945 1.4413314028463158
# epoch : {}, optimizer_target : {} 946 1.4413314028463158
# epoch : {}, optimizer_target : {} 947 1.4413314028463158
# epoch : {}, optimizer_target : {} 948 1.4413314028463158
# epoch : {}, optimizer_target : {} 949 1.4413314028463158
# epoch : {}, optimizer_target : {} 950 1.4413314028463158
# epoch : {}, optimizer_target : {} 951 1.4413314028463158
# epoch : {}, optimizer_target : {} 952 1.4413314028463158
# epoch : {}, optimizer_target : {} 953 1.4413314028463158
# epoch : {}, optimizer_target : {} 954 1.4413314028463158
# epoch : {}, optimizer_target : {} 955 1.4413314028463158
# epoch : {}, optimizer_target : {} 956 1.4413314028463158
# epoch : {}, optimizer_target : {} 957 1.4413314028463158
# epoch : {}, optimizer_target : {} 958 1.4413314028463158
# epoch : {}, optimizer_target : {} 959 1.4413314028463158
# epoch : {}, optimizer_target : {} 960 1.4413314028463158
# epoch : {}, optimizer_target : {} 961 1.4413314028463158
# epoch : {}, optimizer_target : {} 962 1.4413314028463158
# epoch : {}, optimizer_target : {} 963 1.4413314028463158
# epoch : {}, optimizer_target : {} 964 1.4413314028463158
# epoch : {}, optimizer_target : {} 965 1.4413314028463158
# epoch : {}, optimizer_target : {} 966 1.4413314028463158
# epoch : {}, optimizer_target : {} 967 1.4413314028463158
# epoch : {}, optimizer_target : {} 968 1.4413314028463158
# epoch : {}, optimizer_target : {} 969 1.4413314028463158
# epoch : {}, optimizer_target : {} 970 1.4413314028463158
# epoch : {}, optimizer_target : {} 971 1.4413314028463158
# epoch : {}, optimizer_target : {} 972 1.4413314028463158
# epoch : {}, optimizer_target : {} 973 1.4413314028463158
# epoch : {}, optimizer_target : {} 974 1.4413314028463158
# epoch : {}, optimizer_target : {} 975 1.4413314028463158
# epoch : {}, optimizer_target : {} 976 1.4413314028463158
# epoch : {}, optimizer_target : {} 977 1.4413314028463158
# epoch : {}, optimizer_target : {} 978 1.4413314028463158
# epoch : {}, optimizer_target : {} 979 1.4413314028463158
# epoch : {}, optimizer_target : {} 980 1.4413314028463158
# epoch : {}, optimizer_target : {} 981 1.4413314028463158
# epoch : {}, optimizer_target : {} 982 1.4413314028463158
# epoch : {}, optimizer_target : {} 983 1.4413314028463158
# epoch : {}, optimizer_target : {} 984 1.4413314028463158
# epoch : {}, optimizer_target : {} 985 1.4413314028463158
# epoch : {}, optimizer_target : {} 986 1.4413314028463158
# epoch : {}, optimizer_target : {} 987 1.4413314028463158
# epoch : {}, optimizer_target : {} 988 1.4413314028463158
# epoch : {}, optimizer_target : {} 989 1.4413314028463158
# epoch : {}, optimizer_target : {} 990 1.4413314028463158
# epoch : {}, optimizer_target : {} 991 1.4413314028463158
# epoch : {}, optimizer_target : {} 992 1.4413314028463158
# epoch : {}, optimizer_target : {} 993 1.4413314028463158
# epoch : {}, optimizer_target : {} 994 1.4413314028463158
# epoch : {}, optimizer_target : {} 995 1.4413314028463158
# epoch : {}, optimizer_target : {} 996 1.4413314028463158
# epoch : {}, optimizer_target : {} 997 1.4413314028463158
# epoch : {}, optimizer_target : {} 998 1.4413314028463158
# epoch : {}, optimizer_target : {} 999 1.4413314028463158
